# %%
# data
my_list = [['bar', 'bar', 'baz', 'baz', 'foo', 'foo', 'qux', 'qux'],
           ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two']]
my_list
# Out:
# [['bar', 'bar', 'baz', 'baz', 'foo', 'foo', 'qux', 'qux'],
#  ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two']]

# %%
my_tuple = list(zip(*my_list))
my_tuple
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
import pandas as pd
import numpy as np

# %%
my_df = pd.DataFrame(my_tuple)
my_df
# Out:
#      0    1
# 0  bar  one
# 1  bar  two
# 2  baz  one
# 3  baz  two
# 4  foo  one
# 5  foo  two
# 6  qux  one
# 7  qux  two

# %%
my_index = pd.MultiIndex.from_tuples(my_tuple, names=['first', 'second'])
my_index
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            names=['first', 'second'])

# %%
my_ss = pd.Series(np.random.randn(8), index=my_index)
my_ss
# Out:
# first  second
# bar    one       0.005460
#        two       1.596831
# baz    one      -0.114147
#        two      -0.301745
# foo    one       0.349938
#        two       0.030804
# qux    one      -0.433177
#        two       0.441841
# dtype: float64

# %%
my_ss = pd.Series(np.random.randn(8))
my_ss.index = my_index
my_ss
# Out:
# first  second
# bar    one       1.003028
#        two       0.057666
# baz    one       0.695518
#        two      -0.340159
# foo    one       0.584329
#        two       0.142919
# qux    one      -0.010138
#        two       0.590941
# dtype: float64

# %%
my_df.columns=['first', 'second']
my_df['data'] = np.random.randn(8)
my_df
# Out:
#   first second      data
# 0   bar    one -0.720460
# 1   bar    two  0.654503
# 2   baz    one -0.550912
# 3   baz    two -1.066085
# 4   foo    one -0.245493
# 5   foo    two  0.466606
# 6   qux    one -1.549454
# 7   qux    two -2.838980

# %%
my_df.set_index(['first', 'second'])
# Out:
#                   data
# first second
# bar   one    -0.720460
#       two     0.654503
# baz   one    -0.550912
#       two    -1.066085
# foo   one    -0.245493
#       two     0.466606
# qux   one    -1.549454
#       two    -2.838980

# %%
my_df.set_index(['first', 'second']).index
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            names=['first', 'second'])

# %%
my_ss
# Out:
# first  second
# bar    one       1.003028
#        two       0.057666
# baz    one       0.695518
#        two      -0.340159
# foo    one       0.584329
#        two       0.142919
# qux    one      -0.010138
#        two       0.590941
# dtype: float64

# %%
my_list = [['bar', 'baz', 'foo', 'qux'], ['one', 'two']]
my_list
# Out:
# [['bar', 'baz', 'foo', 'qux'], ['one', 'two']]

# %%
my_index = pd.MultiIndex.from_product(my_list)
my_index
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            )

# %%
my_df1 = my_df.iloc[[0, 2, 3, 4, 7]]
my_df1
# my_df2 = my_df1.set_index(['first', 'second'])
# my_df2
# Out:
#   first second      data
# 0   bar    one -0.720460
# 2   baz    one -0.550912
# 3   baz    two -1.066085
# 4   foo    one -0.245493
# 7   qux    two -2.838980

# %%
my_df1['first']
# Out:
# 0    bar
# 2    baz
# 3    baz
# 4    foo
# 7    qux
# Name: first, dtype: object

# %%
my_values1 = list(my_df1['first'].unique())
my_values1
# Out:
# ['bar', 'baz', 'foo', 'qux']

# %%
my_values2 = list(my_df1['second'].unique())
my_values2
# Out:
# ['one', 'two']

# %%
my_index = pd.MultiIndex.from_product([my_values1, my_values2])
my_index
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            )

# %%
my_df2 = my_df1.set_index(['first', 'second'])
my_df2
# Out:
#                   data
# first second
# bar   one    -0.720460
# baz   one    -0.550912
#       two    -1.066085
# foo   one    -0.245493
# qux   two    -2.838980

# %%
my_df2.reindex(my_index)
# Out:
#              data
# bar one -0.720460
#     two       NaN
# baz one -0.550912
#     two -1.066085
# foo one -0.245493
#     two       NaN
# qux one       NaN
#     two -2.838980

# %% [markdown]
# ## resample
# - time series
# - 시간의 간격을 조절

# %%
my_df3 = pd.DataFrame(my_tuple, columns=['first', 'second'])
my_df3
# Out:
#   first second
# 0   bar    one
# 1   bar    two
# 2   baz    one
# 3   baz    two
# 4   foo    one
# 5   foo    two
# 6   qux    one
# 7   qux    two

# %%
my_index = pd.MultiIndex.from_frame(my_df3)
my_index
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            names=['first', 'second'])

# %%
my_ss
# Out:
# first  second
# bar    one       1.003028
#        two       0.057666
# baz    one       0.695518
#        two      -0.340159
# foo    one       0.584329
#        two       0.142919
# qux    one      -0.010138
#        two       0.590941
# dtype: float64

# %%
my_ss['bar']
# Out:
# second
# one    1.003028
# two    0.057666
# dtype: float64

# %%
my_ss['bar']['one']
# Out:
# 1.0030275772983641

# %%
my_ss['bar']
# Out:
# second
# one    1.003028
# two    0.057666
# dtype: float64

# %%
my_ss[:, 'one']
# Out:
# first
# bar    1.003028
# baz    0.695518
# foo    0.584329
# qux   -0.010138
# dtype: float64

# %%
# slice(None) == :

# %%
my_ss[(slice(None), 'one')]
# Out:
# first
# bar    1.003028
# baz    0.695518
# foo    0.584329
# qux   -0.010138
# dtype: float64

# %%
my_index.levels
# Out:
# FrozenList([['bar', 'baz', 'foo', 'qux'], ['one', 'two']])

# %%
my_index.names = ['first', 'second']
my_index
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            names=['first', 'second'])

# %%
my_index.get_level_values(0)
# Out:
# Index(['bar', 'bar', 'baz', 'baz', 'foo', 'foo', 'qux', 'qux'], dtype='object')

# %%
my_index.get_level_values(1)
# Out:
# Index(['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two'], dtype='object')

# %%
my_index.get_level_values('second')
# Out:
# Index(['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two'], dtype='object', name='second')

# %% [markdown]
# # 멀티인덱스의 인덱싱: 4 방법
# - ('first', 'second', ...): 행과 열의 인덱싱 구분
# - 문제: (:, 'one') => 파이썬 문법 에러
#
# - 멀티인덱스의 인덱싱:
#   - slice(None): **:**
#     - 만약 level=4일때,
#       - [slice(None)] == [(slice(None), slice(None), slice(None), slice(None))]
#   - xs:
#     - my_df.xs("one", level=1)
#
#   - pandas.IndexSlice:
#     - my_df.loc[pd.IndexSlice[:, 'one'], pd.IndexSlice[:]]
#     ```python
#     idx = pd.IndexSlice
#     my_df.loc[idx[:, 'one'], idx[:]]
#     ```
#   - my_df.loc(axis='index')[(:, 'one')]

# %%
my_df1
# Out:
#   first second      data
# 0   bar    one -0.720460
# 2   baz    one -0.550912
# 3   baz    two -1.066085
# 4   foo    one -0.245493
# 7   qux    two -2.838980

# %%
my_df1['first'].unique()
# Out:
# array(['bar', 'baz', 'foo', 'qux'], dtype=object)

# %%
my_df1['second'].unique()
# Out:
# array(['one', 'two'], dtype=object)

# %%
my_index = pd.MultiIndex.from_product([my_df1['first'].unique(), my_df1['second'].unique()])
my_index
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            )

# %%
my_df2 = my_df1.set_index(['first', 'second'])
my_df2.reindex(my_index)
# Out:
#              data
# bar one -0.720460
#     two       NaN
# baz one -0.550912
#     two -1.066085
# foo one -0.245493
#     two       NaN
# qux one       NaN
#     two -2.838980

# %%
def mklbl(prefix, n):
  return [f"{prefix}{i}" for i in range(n)]

# %%
my_index1 = pd.MultiIndex.from_product([mklbl("A", 4), mklbl("B",2),mklbl("C", 4), mklbl("D",2)])
my_index1
# Out:
# MultiIndex([('A0', 'B0', 'C0', 'D0'),
#             ('A0', 'B0', 'C0', 'D1'),
#             ('A0', 'B0', 'C1', 'D0'),
#             ('A0', 'B0', 'C1', 'D1'),
#             ('A0', 'B0', 'C2', 'D0'),
#             ('A0', 'B0', 'C2', 'D1'),
#             ('A0', 'B0', 'C3', 'D0'),
#             ('A0', 'B0', 'C3', 'D1'),
#             ('A0', 'B1', 'C0', 'D0'),
#             ('A0', 'B1', 'C0', 'D1'),
#             ('A0', 'B1', 'C1', 'D0'),
#             ('A0', 'B1', 'C1', 'D1'),
#             ('A0', 'B1', 'C2', 'D0'),
#             ('A0', 'B1', 'C2', 'D1'),
#             ('A0', 'B1', 'C3', 'D0'),
#             ('A0', 'B1', 'C3', 'D1'),
#             ('A1', 'B0', 'C0', 'D0'),
#             ('A1', 'B0', 'C0', 'D1'),
#             ('A1', 'B0', 'C1', 'D0'),
#             ('A1', 'B0', 'C1', 'D1'),
#             ('A1', 'B0', 'C2', 'D0'),
#             ('A1', 'B0', 'C2', 'D1'),
#             ('A1', 'B0', 'C3', 'D0'),
#             ('A1', 'B0', 'C3', 'D1'),
#             ('A1', 'B1', 'C0', 'D0'),
#             ('A1', 'B1', 'C0', 'D1'),
#             ('A1', 'B1', 'C1', 'D0'),
#             ('A1', 'B1', 'C1', 'D1'),
#             ('A1', 'B1', 'C2', 'D0'),
#             ('A1', 'B1', 'C2', 'D1'),
#             ('A1', 'B1', 'C3', 'D0'),
#             ('A1', 'B1', 'C3', 'D1'),
#             ('A2', 'B0', 'C0', 'D0'),
#             ('A2', 'B0', 'C0', 'D1'),
#             ('A2', 'B0', 'C1', 'D0'),
#             ('A2', 'B0', 'C1', 'D1'),
#             ('A2', 'B0', 'C2', 'D0'),
#             ('A2', 'B0', 'C2', 'D1'),
#             ('A2', 'B0', 'C3', 'D0'),
#             ('A2', 'B0', 'C3', 'D1'),
#             ('A2', 'B1', 'C0', 'D0'),
#             ('A2', 'B1', 'C0', 'D1'),
#             ('A2', 'B1', 'C1', 'D0'),
#             ('A2', 'B1', 'C1', 'D1'),
#             ('A2', 'B1', 'C2', 'D0'),
#             ('A2', 'B1', 'C2', 'D1'),
#             ('A2', 'B1', 'C3', 'D0'),
#             ('A2', 'B1', 'C3', 'D1'),
#             ('A3', 'B0', 'C0', 'D0'),
#             ('A3', 'B0', 'C0', 'D1'),
#             ('A3', 'B0', 'C1', 'D0'),
#             ('A3', 'B0', 'C1', 'D1'),
#             ('A3', 'B0', 'C2', 'D0'),
#             ('A3', 'B0', 'C2', 'D1'),
#             ('A3', 'B0', 'C3', 'D0'),
#             ('A3', 'B0', 'C3', 'D1'),
#             ('A3', 'B1', 'C0', 'D0'),
#             ('A3', 'B1', 'C0', 'D1'),
#             ('A3', 'B1', 'C1', 'D0'),
#             ('A3', 'B1', 'C1', 'D1'),
#             ('A3', 'B1', 'C2', 'D0'),
#             ('A3', 'B1', 'C2', 'D1'),
#             ('A3', 'B1', 'C3', 'D0'),
#             ('A3', 'B1', 'C3', 'D1')],
#            )

# %%
my_tuples = [("a", "foo"),
             ("a", "bar"),
             ("b", "foo"),
             ("b", "bar")]
my_tuples
# Out:
# [('a', 'foo'), ('a', 'bar'), ('b', 'foo'), ('b', 'bar')]

# %%
my_columns = pd.MultiIndex.from_tuples(my_tuples)
my_columns.names = ["lvl1", "lvl2"]
my_columns
# Out:
# MultiIndex([('a', 'foo'),
#             ('a', 'bar'),
#             ('b', 'foo'),
#             ('b', 'bar')],
#            names=['lvl1', 'lvl2'])

# %%
my_df4 = pd.DataFrame(np.random.randn(64,4))
my_df4.index = my_index1
my_df4.columns = my_columns
my_df4
# Out:
# lvl1                a                   b
# lvl2              foo       bar       foo       bar
# A0 B0 C0 D0  1.422259  0.590082 -0.825660  0.187919
#          D1 -0.647367  0.295819  0.132092 -0.900961
#       C1 D0 -0.304251  0.687993  0.220666  0.346400
#          D1 -1.339309  0.419649 -2.196751 -2.364795
#       C2 D0 -0.341583 -1.026412 -0.616736  1.336479
# ...               ...       ...       ...       ...
# A3 B1 C1 D1  0.842709  0.284690 -1.369467 -0.106890
#       C2 D0  2.598058 -0.939699  1.063707 -0.952107
#          D1  0.017764 -0.393298 -0.258957 -0.403932
#       C3 D0 -1.917656  0.020950  1.076381  0.686760
#          D1 -1.487816  0.271708  0.429282  0.481335
#
# [64 rows x 4 columns]

# %%
my_df4.loc[(slice(None), "B0"), :]
# Out:
# lvl1                a                   b
# lvl2              foo       bar       foo       bar
# A0 B0 C0 D0  1.422259  0.590082 -0.825660  0.187919
#          D1 -0.647367  0.295819  0.132092 -0.900961
#       C1 D0 -0.304251  0.687993  0.220666  0.346400
#          D1 -1.339309  0.419649 -2.196751 -2.364795
#       C2 D0 -0.341583 -1.026412 -0.616736  1.336479
#          D1  1.520603  0.141936  0.132799 -0.216547
#       C3 D0  0.185525  0.455075 -0.371240  0.298843
#          D1  0.113742  2.296014  0.272868 -2.788831
# A1 B0 C0 D0  0.555333 -0.798306 -1.135883 -0.528272
#          D1  1.397261 -0.461011  0.255026  0.434483
#       C1 D0 -0.202053  0.060489  0.224152 -0.509321
#          D1 -1.655338  0.214828  0.136785 -2.075243
#       C2 D0  1.606483  0.614421  0.823805  0.525965
#          D1  1.890792  0.947016  1.432739  0.293245
#       C3 D0 -0.653294 -0.326236 -0.317929 -0.242309
#          D1  0.427529  0.870026  2.337021 -0.726131
# A2 B0 C0 D0 -0.496394 -0.386589 -1.549845  0.506384
#          D1  1.097179  0.919374  0.310395  0.350585
#       C1 D0  0.362606  1.586947 -1.471473 -0.003251
#          D1  0.559896 -0.383799  0.516352  2.028165
#       C2 D0  0.089436 -0.538223 -0.217019 -1.871428
#          D1 -0.682038 -2.785028 -0.254811 -0.407834
#       C3 D0  0.768992 -0.090472 -0.074354 -0.424894
#          D1  0.435417 -0.787503 -0.603149  0.036424
# A3 B0 C0 D0  0.240642  0.700154  0.955237  1.104982
#          D1 -1.672545 -1.242459 -1.128771 -1.249687
#       C1 D0  0.992449 -1.403506 -0.659074 -1.186311
#          D1 -0.833652 -1.420311 -0.436763 -1.148822
#       C2 D0 -0.733981  0.853940 -1.174471  0.125214
#          D1  1.231063  0.339655  0.406481 -1.884409
#       C3 D0 -0.017741  0.911953 -1.260954  0.293230
#          D1  0.092736 -0.087313 -0.412475  0.231729

# %% [markdown]
# ## Cross Section (단면)

# %%
my_df4.xs("B0", level=1).shape
# Out:
# (32, 4)

# %%
my_df4.xs("B0", level=1)
# Out:
# lvl1             a                   b
# lvl2           foo       bar       foo       bar
# A0 C0 D0  1.422259  0.590082 -0.825660  0.187919
#       D1 -0.647367  0.295819  0.132092 -0.900961
#    C1 D0 -0.304251  0.687993  0.220666  0.346400
#       D1 -1.339309  0.419649 -2.196751 -2.364795
#    C2 D0 -0.341583 -1.026412 -0.616736  1.336479
#       D1  1.520603  0.141936  0.132799 -0.216547
#    C3 D0  0.185525  0.455075 -0.371240  0.298843
#       D1  0.113742  2.296014  0.272868 -2.788831
# A1 C0 D0  0.555333 -0.798306 -1.135883 -0.528272
#       D1  1.397261 -0.461011  0.255026  0.434483
#    C1 D0 -0.202053  0.060489  0.224152 -0.509321
#       D1 -1.655338  0.214828  0.136785 -2.075243
#    C2 D0  1.606483  0.614421  0.823805  0.525965
#       D1  1.890792  0.947016  1.432739  0.293245
#    C3 D0 -0.653294 -0.326236 -0.317929 -0.242309
#       D1  0.427529  0.870026  2.337021 -0.726131
# A2 C0 D0 -0.496394 -0.386589 -1.549845  0.506384
#       D1  1.097179  0.919374  0.310395  0.350585
#    C1 D0  0.362606  1.586947 -1.471473 -0.003251
#       D1  0.559896 -0.383799  0.516352  2.028165
#    C2 D0  0.089436 -0.538223 -0.217019 -1.871428
#       D1 -0.682038 -2.785028 -0.254811 -0.407834
#    C3 D0  0.768992 -0.090472 -0.074354 -0.424894
#       D1  0.435417 -0.787503 -0.603149  0.036424
# A3 C0 D0  0.240642  0.700154  0.955237  1.104982
#       D1 -1.672545 -1.242459 -1.128771 -1.249687
#    C1 D0  0.992449 -1.403506 -0.659074 -1.186311
#       D1 -0.833652 -1.420311 -0.436763 -1.148822
#    C2 D0 -0.733981  0.853940 -1.174471  0.125214
#       D1  1.231063  0.339655  0.406481 -1.884409
#    C3 D0 -0.017741  0.911953 -1.260954  0.293230
#       D1  0.092736 -0.087313 -0.412475  0.231729

# %%
my_df4.loc[pd.IndexSlice[:, "B0"], :]
# Out:
# lvl1                a                   b
# lvl2              foo       bar       foo       bar
# A0 B0 C0 D0  1.422259  0.590082 -0.825660  0.187919
#          D1 -0.647367  0.295819  0.132092 -0.900961
#       C1 D0 -0.304251  0.687993  0.220666  0.346400
#          D1 -1.339309  0.419649 -2.196751 -2.364795
#       C2 D0 -0.341583 -1.026412 -0.616736  1.336479
#          D1  1.520603  0.141936  0.132799 -0.216547
#       C3 D0  0.185525  0.455075 -0.371240  0.298843
#          D1  0.113742  2.296014  0.272868 -2.788831
# A1 B0 C0 D0  0.555333 -0.798306 -1.135883 -0.528272
#          D1  1.397261 -0.461011  0.255026  0.434483
#       C1 D0 -0.202053  0.060489  0.224152 -0.509321
#          D1 -1.655338  0.214828  0.136785 -2.075243
#       C2 D0  1.606483  0.614421  0.823805  0.525965
#          D1  1.890792  0.947016  1.432739  0.293245
#       C3 D0 -0.653294 -0.326236 -0.317929 -0.242309
#          D1  0.427529  0.870026  2.337021 -0.726131
# A2 B0 C0 D0 -0.496394 -0.386589 -1.549845  0.506384
#          D1  1.097179  0.919374  0.310395  0.350585
#       C1 D0  0.362606  1.586947 -1.471473 -0.003251
#          D1  0.559896 -0.383799  0.516352  2.028165
#       C2 D0  0.089436 -0.538223 -0.217019 -1.871428
#          D1 -0.682038 -2.785028 -0.254811 -0.407834
#       C3 D0  0.768992 -0.090472 -0.074354 -0.424894
#          D1  0.435417 -0.787503 -0.603149  0.036424
# A3 B0 C0 D0  0.240642  0.700154  0.955237  1.104982
#          D1 -1.672545 -1.242459 -1.128771 -1.249687
#       C1 D0  0.992449 -1.403506 -0.659074 -1.186311
#          D1 -0.833652 -1.420311 -0.436763 -1.148822
#       C2 D0 -0.733981  0.853940 -1.174471  0.125214
#          D1  1.231063  0.339655  0.406481 -1.884409
#       C3 D0 -0.017741  0.911953 -1.260954  0.293230
#          D1  0.092736 -0.087313 -0.412475  0.231729

# %%
my_df4.xs(('A2', 'B0'), level=(0, 1))
# Out:
# lvl1          a                   b
# lvl2        foo       bar       foo       bar
# C0 D0 -0.496394 -0.386589 -1.549845  0.506384
#    D1  1.097179  0.919374  0.310395  0.350585
# C1 D0  0.362606  1.586947 -1.471473 -0.003251
#    D1  0.559896 -0.383799  0.516352  2.028165
# C2 D0  0.089436 -0.538223 -0.217019 -1.871428
#    D1 -0.682038 -2.785028 -0.254811 -0.407834
# C3 D0  0.768992 -0.090472 -0.074354 -0.424894
#    D1  0.435417 -0.787503 -0.603149  0.036424

# %% [markdown]
# ### take 메서드

# %%
my_df4.take?

# %%
my_df4.take([0, 16, 32, 48], axis="index")
# Out:
# lvl1                a                   b
# lvl2              foo       bar       foo       bar
# A0 B0 C0 D0  1.422259  0.590082 -0.825660  0.187919
# A1 B0 C0 D0  0.555333 -0.798306 -1.135883 -0.528272
# A2 B0 C0 D0 -0.496394 -0.386589 -1.549845  0.506384
# A3 B0 C0 D0  0.240642  0.700154  0.955237  1.104982

# %%
my_df4.iloc[[0, 16, 32, 48]]
# Out:
# lvl1                a                   b
# lvl2              foo       bar       foo       bar
# A0 B0 C0 D0  1.422259  0.590082 -0.825660  0.187919
# A1 B0 C0 D0  0.555333 -0.798306 -1.135883 -0.528272
# A2 B0 C0 D0 -0.496394 -0.386589 -1.549845  0.506384
# A3 B0 C0 D0  0.240642  0.700154  0.955237  1.104982

# %%
my_df1
# Out:
#   first second      data
# 0   bar    one -0.720460
# 2   baz    one -0.550912
# 3   baz    two -1.066085
# 4   foo    one -0.245493
# 7   qux    two -2.838980

# %%
my_df2
# Out:
#                   data
# first second
# bar   one    -0.720460
# baz   one    -0.550912
#       two    -1.066085
# foo   one    -0.245493
# qux   two    -2.838980

# %%
my_df2.loc[("bar","one"):("baz","two")]
# Out:
#                   data
# first second
# bar   one    -0.720460
# baz   one    -0.550912
#       two    -1.066085

# %% [markdown]
# ### slice
# - slice(3) == [:3]
# - slice(1,3) == [1:3]
# - slice(1,3,2) == [1:3:2]

# %%
my_df2.loc[slice(("bar", "one"), ("baz", "two"))]
# Out:
#                   data
# first second
# bar   one    -0.720460
# baz   one    -0.550912
#       two    -1.066085
