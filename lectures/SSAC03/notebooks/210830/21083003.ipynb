# %%
import numpy as np
import pandas as pd

# %%
my_list = list(range(5))
my_list
# Out:
# [0, 1, 2, 3, 4]

# %%
my_dict = {
    "a": 100,
    "b": 200,
    "c": 300,
    "d": 400,
    "e": 500
}
my_dict
# Out:
# {'a': 100, 'b': 200, 'c': 300, 'd': 400, 'e': 500}

# %%
my_ss1 = pd.Series(my_list)

# %%
my_ss2 = pd.Series(my_list, index=["a", "b", "c", "d", "e"])
my_ss
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %% [markdown]
# # Series의 인덱싱
# - python 인덱싱과 차이가 있다.
#
# - 위치
#   - my_ss.iloc
#
# - 라벨(인덱스)
#   - dict 형식 표현: my_ss[label]
#   - my_ss.label
#   - my_ss.loc

# %% [markdown]
# ## Series 인덱싱: No Label (Default Index): 안티패턴
#
# - 순서를 이용한 인덱싱은 iloc을 이용한다.
# - 인덱스가 주어지지 않을 경우 RangeIndex가 자동 생성된다.

# %%
my_ss
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
my_ss.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
my_ss.iloc[0]
# Out:
# 0

# %%
my_ss.iloc[2]
# Out:
# 2

# %%
my_ss.iloc[-1]
# Out:
# 4

# %%
my_ss[0] # 우연히 라벨 0이 존재
# Out:
# 0

# %%
my_ss.loc[0]
# Out:
# 0

# %%
my_ss[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     354                 try:
# --> 355                     return self._range.index(new_key)
#     356                 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-99-ad77634298e9> in <module>()
# ----> 1 my_ss[-1]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     880
#     881         elif key_is_scalar:
# --> 882             return self._get_value(key)
#     883
#     884         if is_hashable(key):
#
# ...

# %%
my_ss.loc[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     354                 try:
# --> 355                     return self._range.index(new_key)
#     356                 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-e65f0826b673> in <module>()
# ----> 1 my_ss.loc[-1]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ...

# %% [markdown]
# ## 리스트 인덱싱
# - iloc:
#   - 순서 (Python의 인덱스와 동일)
#   - bool 리스트: 값의 크기가 같아야 한다.
# - loc:
#   - 이름
#   - bool 리스트: 값의 크기가 같아야 한다.

# %%
my_ss.iloc[[0, 1]]
# Out:
# 0    0
# 1    1
# dtype: int64

# %%
my_ss.iloc[[True, False, True, False, True]]
# Out:
# 0    0
# 2    2
# 4    4
# dtype: int64

# %%
my_ss>2
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# dtype: bool

# %%
my_ss[[0, 1]]
# Out:
# 0    0
# 1    1
# dtype: int64

# %%
my_ss.loc[[0, 1]]
# Out:
# 0    0
# 1    1
# dtype: int64

# %%
my_ss
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
my_ss2
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# dtype: int64

# %%
my_ss2.iloc[0]
# Out:
# 0

# %%
my_ss2.iloc[-1]
# Out:
# 4

# %%
my_ss3 = pd.Series(my_list, index=['a', 'b', 'c', 0, 'e'])
my_ss3
# Out:
# a    0
# b    1
# c    2
# 0    3
# e    4
# dtype: int64

# %%
my_ss2[0]
# Out:
# 0

# %%
my_ss2['a']
# Out:
# 0

# %%
my_ss3[0]
# Out:
# 3

# %%
my_ss3['a']
# Out:
# 0

# %%
my_ss2.loc['a']
# Out:
# 0

# %%
my_ss3.loc['a']
# Out:
# 0

# %%
my_ss2.iloc[[0, 2]]
# Out:
# a    0
# c    2
# dtype: int64

# %%
my_ss2.iloc[[True, False, True, False, True]]
# Out:
# a    0
# c    2
# e    4
# dtype: int64

# %%
my_ss2[['a', 'b']]
# Out:
# a    0
# b    1
# dtype: int64

# %%
my_ss2.loc[['a', 'b']]
# Out:
# a    0
# b    1
# dtype: int64

# %%
my_ss2[[True, False, True, False, True]]
# Out:
# a    0
# c    2
# e    4
# dtype: int64

# %%
my_ss2[[True, False, True, False, True]]
# Out:
# a    0
# c    2
# e    4
# dtype: int64

# %% [markdown]
# Series 슬라이싱
# - 값의 위치:
#   - my_ss.iloc[start:end] (파이썬의 인덱싱/슬라싱과 동일)
#
# - 라벨
#   - my_ss.loc[start:end] (값의 이름)
#   - my_ss[start:end]

# %%
my_ss1.iloc[:3]
# Out:
# 0    0
# 1    1
# 2    2
# dtype: int64

# %%
my_ss1.iloc[3:]
# Out:
# 3    3
# 4    4
# dtype: int64

# %%
my_ss1.iloc[1:4]
# Out:
# 1    1
# 2    2
# 3    3
# dtype: int64

# %%
my_ss2.iloc[:3]
# Out:
# a    0
# b    1
# c    2
# dtype: int64

# %%
my_ss2.iloc[3:]
# Out:
# d    3
# e    4
# dtype: int64

# %%
my_ss2.iloc[1:4]
# Out:
# b    1
# c    2
# d    3
# dtype: int64

# %%
my_ss2['a':'c']
# Out:
# a    0
# b    1
# c    2
# dtype: int64

# %%
my_ss2.loc['a': 'c']
# Out:
# a    0
# b    1
# c    2
# dtype: int64

# %%
my_ss2[:'c']
# Out:
# a    0
# b    1
# c    2
# dtype: int64

# %%
my_ss2.loc[:'c']
# Out:
# a    0
# b    1
# c    2
# dtype: int64

# %%
my_ss2['c':]
# Out:
# c    2
# d    3
# e    4
# dtype: int64

# %%
my_ss2.loc['c':]
# Out:
# c    2
# d    3
# e    4
# dtype: int64
