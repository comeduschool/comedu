# %%
import numpy as np
import pandas as pd

# %%
my_dict = {
    "kor": {
        "a": 10,
        "b": 30,
        "c": 50,
        "d": 70
    },
    "eng": {
        "a": 20,
        "b": 40,
        "c": 60,
        "d": 80
    },
    "math": {
        "a": 10,
        "b": 20,
        "c": 10,
        "d": 20
    }
}
my_dict
# Out:
# {'eng': {'a': 20, 'b': 40, 'c': 60, 'd': 80},
#  'kor': {'a': 10, 'b': 30, 'c': 50, 'd': 70},
#  'math': {'a': 10, 'b': 20, 'c': 10, 'd': 20}}

# %%
my_df = pd.DataFrame(my_dict)
my_df
# Out:
#    kor  eng  math
# a   10   20    10
# b   30   40    20
# c   50   60    10
# d   70   80    20

# %% [markdown]
# # Summarization Data
# - count
# - value_counts
# - unique
# - nunique
#
# - sum
# - cumsum
#
# - mean
# - median
# - std
# - var
# - skew
# - kurt
#
# - quantile
# - describe

# %%
my_df2 = my_df.copy()
my_df2.loc['a':'b', 'kor'] = np.nan
my_df2
# Out:
#     kor  eng  math
# a   NaN   20    10
# b   NaN   40    20
# c  50.0   60    10
# d  70.0   80    20

# %%
my_df.count()
# Out:
# kor     4
# eng     4
# math    4
# dtype: int64

# %%
my_df2.count()
# Out:
# kor     2
# eng     4
# math    4
# dtype: int64

# %%
my_df2.shape
# Out:
# (4, 3)

# %%
my_df2[my_df2.kor.isna()]
# Out:
#    kor  eng  math
# a  NaN   20    10
# b  NaN   40    20

# %%
my_nan = ["", "NA", "0", 0, -1, np.nan]
my_nan
# Out:
# ['', 'NA', '0', 0, -1, nan]

# %%
my_df.value_counts()
# Out:
# kor  eng  math
# 70   80   20      1
# 50   60   10      1
# 30   40   20      1
# 10   20   10      1
# dtype: int64

# %%
my_df.kor.value_counts()
# Out:
# 70    1
# 30    1
# 10    1
# 50    1
# Name: kor, dtype: int64

# %%
my_df.math.unique()
# Out:
# array([10, 20])

# %%
my_df.math.nunique()
# Out:
# 2

# %%
my_df.sum()
# Out:
# kor     160
# eng     200
# math     60
# dtype: int64

# %% [markdown]
# ### index vs columns
# - index (0):
#   - 값을 계산: 행 추가
#   - 값을 할당: 행별
# - columns (1):
#   - 값을 계산: 열 추가
#   - 값을 할당: 열별
# - 2 이상

# %%
my_df
# Out:
#    kor  eng  math
# a   10   20    10
# b   30   40    20
# c   50   60    10
# d   70   80    20

# %%
my_df.sum(axis='index')
# Out:
# kor     160
# eng     200
# math     60
# dtype: int64

# %%
my_df.sum(axis=0)
# Out:
# kor     160
# eng     200
# math     60
# dtype: int64

# %%
my_df.sum(axis='columns')
# Out:
# a     40
# b     90
# c    120
# d    170
# dtype: int64

# %%
my_df.cumsum()
# Out:
#    kor  eng  math
# a   10   20    10
# b   40   60    30
# c   90  120    40
# d  160  200    60

# %%
my_df.mean()
# Out:
# kor     40.0
# eng     50.0
# math    15.0
# dtype: float64

# %%
my_df.median()
# Out:
# kor     40.0
# eng     50.0
# math    15.0
# dtype: float64

# %%
my_df.std()
# Out:
# kor     25.819889
# eng     25.819889
# math     5.773503
# dtype: float64

# %%
my_df.quantile([.25, .5, 0.75])
# Out:
#        kor   eng  math
# 0.25  25.0  35.0  10.0
# 0.50  40.0  50.0  15.0
# 0.75  55.0  65.0  20.0

# %%
my_df2['Result'] = ['통과', '탈락', '통과', '탈락']
my_df2
# Out:
#     kor  eng  math Result
# a   NaN   20    10     통과
# b   NaN   40    20     탈락
# c  50.0   60    10     통과
# d  70.0   80    20     탈락

# %%
my_df2.describe()
# Out:
#              kor        eng       math
# count   2.000000   4.000000   4.000000
# mean   60.000000  50.000000  15.000000
# std    14.142136  25.819889   5.773503
# min    50.000000  20.000000  10.000000
# 25%    55.000000  35.000000  10.000000
# 50%    60.000000  50.000000  15.000000
# 75%    65.000000  65.000000  20.000000
# max    70.000000  80.000000  20.000000

# %%
my_df2.describe(include=['O']) # 'O': 파이썬 기본 객체 (str)
# Out:
#        Result
# count       4
# unique      2
# top        통과
# freq        2

# %% [markdown]
# ## Data Reshape
# - assign
# - drop_duplicates
# - drop
# - dropna

# %%
my_df.shape
# Out:
# (4, 3)

# %%
my_df2.math.shape
# Out:
# (4,)

# %%
my_df2.math.drop_duplicates()
# Out:
# a    10
# b    20
# Name: math, dtype: int64

# %%
my_df2.math.drop_duplicates().shape
# Out:
# (2,)

# %%
my_df2.drop('a')
# Out:
#     kor  eng  math Result
# b   NaN   40    20     탈락
# c  50.0   60    10     통과
# d  70.0   80    20     탈락

# %%
my_df2.drop(['a', 'b'])
# Out:
#     kor  eng  math Result
# c  50.0   60    10     통과
# d  70.0   80    20     탈락

# %%
my_df2.drop('a', axis='index')
# Out:
#     kor  eng  math Result
# b   NaN   40    20     탈락
# c  50.0   60    10     통과
# d  70.0   80    20     탈락

# %%
my_df2.drop(['a', 'b'], axis='index')
# Out:
#     kor  eng  math Result
# c  50.0   60    10     통과
# d  70.0   80    20     탈락

# %%
my_df2.shape
# Out:
# (4, 4)

# %%
my_df2.drop(['a', 'b'], axis='index').shape
# Out:
# (2, 4)

# %%
my_df2.drop('Result', axis='columns')
# Out:
#     kor  eng  math
# a   NaN   20    10
# b   NaN   40    20
# c  50.0   60    10
# d  70.0   80    20

# %%
my_df2.drop('Result', axis='columns').shape
# Out:
# (4, 3)

# %%
my_df2.drop(index=['a', 'b'])
# Out:
#     kor  eng  math Result
# c  50.0   60    10     통과
# d  70.0   80    20     탈락

# %%
my_df2.drop(columns=['Result'])
# Out:
#     kor  eng  math
# a   NaN   20    10
# b   NaN   40    20
# c  50.0   60    10
# d  70.0   80    20

# %%
my_df2.dropna()
# Out:
#     kor  eng  math Result
# c  50.0   60    10     통과
# d  70.0   80    20     탈락

# %%
my_df2.dropna(axis='index')
# Out:
#     kor  eng  math Result
# c  50.0   60    10     통과
# d  70.0   80    20     탈락

# %%
my_df2.dropna(axis='columns')
# Out:
#    eng  math Result
# a   20    10     통과
# b   40    20     탈락
# c   60    10     통과
# d   80    20     탈락

# %%
my_df2.assign(kor_final=lambda m:  2*m.kor)
# Out:
#     kor  eng  math Result  kor_final
# a   NaN   20    10     통과        NaN
# b   NaN   40    20     탈락        NaN
# c  50.0   60    10     통과      100.0
# d  70.0   80    20     탈락      140.0

# %%
my_df2['kor_mid'] = my_df2.kor / 2
my_df2
# Out:
#     kor  eng  math Result  kor_mid
# a   NaN   20    10     통과      NaN
# b   NaN   40    20     탈락      NaN
# c  50.0   60    10     통과     25.0
# d  70.0   80    20     탈락     35.0

# %% [markdown]
# ## Index Manipulation
# - values
# - index
# - rename
# - reindex

# %%
my_df2 = my_df.copy()
my_df2.columns = ["국어", "영어", "수학"]
my_df2.index = [idx*2 for idx in my_df2.index]
my_df2 = my_df2 * 2

# %%
my_df.values[:, :]
# Out:
# array([[10, 20, 10],
#        [30, 40, 20],
#        [50, 60, 10],
#        [70, 80, 20]])

# %%
my_df # (국어, aa) 존재 하지 않음.
# Out:
#    kor  eng  math
# a   10   20    10
# b   30   40    20
# c   50   60    10
# d   70   80    20

# %%
my_df2
# Out:
#      국어   영어  수학
# aa   20   40  20
# bb   60   80  40
# cc  100  120  20
# dd  140  160  40

# %%
my_df.values[2:4, 0:2]
# Out:
# array([[50, 60],
#        [70, 80]])

# %%
my_df2.iloc[2:4, 0:2] = my_df.values[2:4, 0:2]
my_df2
# Out:
#     국어  영어  수학
# aa  20  40  20
# bb  60  80  40
# cc  50  60  20
# dd  70  80  40

# %%
my_df.values
# Out:
# array([[10, 20, 10],
#        [30, 40, 20],
#        [50, 60, 10],
#        [70, 80, 20]])

# %%
my_df2
# Out:
#     국어  영어  수학
# aa  20  40  20
# bb  60  80  40
# cc  50  60  20
# dd  70  80  40

# %%
my_df2.index = ['a', 'b', 'c', 'd']
my_df2
# Out:
#    국어  영어  수학
# a  20  40  20
# b  60  80  40
# c  50  60  20
# d  70  80  40

# %%
my_df2.columns = ['kor_final', 'eng_final', 'math_final']
my_df2
# Out:
#    kor_final  eng_final  math_final
# a         20         40          20
# b         60         80          40
# c         50         60          20
# d         70         80          40

# %%
my_df2.rename({'a': 'a2'})
# Out:
#     kor_final  eng_final  math_final
# a2         20         40          20
# b          60         80          40
# c          50         60          20
# d          70         80          40

# %%
my_df2.rename({'a': 'a2'}, axis='index')
# Out:
#     kor_final  eng_final  math_final
# a2         20         40          20
# b          60         80          40
# c          50         60          20
# d          70         80          40

# %%
my_df2.rename(index={'a': 'a2'})
# Out:
#     kor_final  eng_final  math_final
# a2         20         40          20
# b          60         80          40
# c          50         60          20
# d          70         80          40

# %%
my_df2.rename({"kor_final": "kor_mid"}, axis='columns')
# Out:
#    kor_mid  eng_final  math_final
# a       20         40          20
# b       60         80          40
# c       50         60          20
# d       70         80          40

# %%
my_df2.rename(columns={"kor_final": "kor_mid"})
# Out:
#    kor_mid  eng_final  math_final
# a       20         40          20
# b       60         80          40
# c       50         60          20
# d       70         80          40

# %%
my_df2.index = ["a", "b"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-33b5066c4e6f> in <module>()
# ----> 1 my_df2.index = ["a", "b"]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5152         try:
#    5153             object.__getattribute__(self, name)
# -> 5154             return object.__setattr__(self, name, value)
#    5155         except AttributeError:
#    5156             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     562     def _set_axis(self, axis: int, labels: Index) -> None:
#     563         labels = ensure_index(labels)
# --> 564         self._mgr.set_axis(axis, labels)
#     565         self._clear_item_cache()
#     566
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     225         if new_len != old_len:
#     226             raise ValueError(
# --> 227                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     228                 f"values have {new_len} elements"
#     229             )
#
# ValueError: Length mismatch: Expected axis has 4 elements, new values have 2 elements

# %%
my_df2.reindex(["b", "a", "aa"]) # index + reshape
# Out:
#     kor_final  eng_final  math_final
# b        60.0       80.0        40.0
# a        20.0       40.0        20.0
# aa        NaN        NaN         NaN

# %% [markdown]
# ## Sorting
# - sort_index
#   - ascending
#   - na_position
#   - method
#
# - sort_values
#   - ascending
#   - na_position
#   - method

# %%
my_df2
# Out:
#    kor_final  eng_final  math_final
# a         20         40          20
# b         60         80          40
# c         50         60          20
# d         70         80          40

# %%
my_df2.index = [np.nan, 'b', 'c', 'd']
my_df2.kor_final = [np.nan, np.nan, 50, 70]
my_df2
# Out:
#      kor_final  eng_final  math_final
# NaN        NaN         40          20
# b          NaN         80          40
# c         50.0         60          20
# d         70.0         80          40

# %%
my_df.sort_index()
# Out:
#    kor  eng  math
# a   10   20    10
# b   30   40    20
# c   50   60    10
# d   70   80    20

# %%
my_df.sort_index(ascending=True)
# Out:
#    kor  eng  math
# a   10   20    10
# b   30   40    20
# c   50   60    10
# d   70   80    20

# %%
my_df.sort_index(ascending=False)
# Out:
#    kor  eng  math
# d   70   80    20
# c   50   60    10
# b   30   40    20
# a   10   20    10

# %%
my_df2
# Out:
#      kor_final  eng_final  math_final
# NaN        NaN         40          20
# b          NaN         80          40
# c         50.0         60          20
# d         70.0         80          40

# %%
my_df2.sort_index()
# Out:
#      kor_final  eng_final  math_final
# b          NaN         80          40
# c         50.0         60          20
# d         70.0         80          40
# NaN        NaN         40          20

# %%
my_df2.sort_index(na_position='last')
# Out:
#      kor_final  eng_final  math_final
# b          NaN         80          40
# c         50.0         60          20
# d         70.0         80          40
# NaN        NaN         40          20

# %%
my_df2.sort_index(na_position='first')
# Out:
#      kor_final  eng_final  math_final
# NaN        NaN         40          20
# b          NaN         80          40
# c         50.0         60          20
# d         70.0         80          40

# %%
my_df2.sort_index(kind='quicksort')
# Out:
#      kor_final  eng_final  math_final
# b          NaN         80          40
# c         50.0         60          20
# d         70.0         80          40
# NaN        NaN         40          20

# %%
my_df2.sort_index(kind='mergesort')
# Out:
#      kor_final  eng_final  math_final
# b          NaN         80          40
# c         50.0         60          20
# d         70.0         80          40
# NaN        NaN         40          20

# %%
my_df.sort_values('kor')
# Out:
#    kor  eng  math
# a   10   20    10
# b   30   40    20
# c   50   60    10
# d   70   80    20

# %%
my_df2.sort_values('kor_final')
# Out:
#      kor_final  eng_final  math_final
# c         50.0         60          20
# d         70.0         80          40
# NaN        NaN         40          20
# b          NaN         80          40

# %%
my_df2.sort_values('kor_final', na_position='first')
# Out:
#      kor_final  eng_final  math_final
# NaN        NaN         40          20
# b          NaN         80          40
# c         50.0         60          20
# d         70.0         80          40

# %%
my_df2.sort_values('kor_final', kind='quicksort')
# Out:
#      kor_final  eng_final  math_final
# c         50.0         60          20
# d         70.0         80          40
# NaN        NaN         40          20
# b          NaN         80          40

# %%
my_df2.sort_values('kor_final', na_position='first')
# Out:
#      kor_final  eng_final  math_final
# NaN        NaN         40          20
# b          NaN         80          40
# c         50.0         60          20
# d         70.0         80          40

# %% [markdown]
# ## Observation

# %%
my_df.rank()
# Out:
#    kor  eng  math
# a  1.0  1.0   1.5
# b  2.0  2.0   3.5
# c  3.0  3.0   1.5
# d  4.0  4.0   3.5

# %%
my_df.rank?

# %%
my_df.rank(method='average')
# Out:
#    kor  eng  math
# a  1.0  1.0   1.5
# b  2.0  2.0   3.5
# c  3.0  3.0   1.5
# d  4.0  4.0   3.5

# %%
my_df.rank(method='min')
# Out:
#    kor  eng  math
# a  1.0  1.0   1.0
# b  2.0  2.0   3.0
# c  3.0  3.0   1.0
# d  4.0  4.0   3.0
