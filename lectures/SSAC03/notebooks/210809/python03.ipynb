# %% [markdown]
# # 기본 데이터 구조
# - 리스트(list)
# - 튜플(tuple)
# - 집합(set)
# - 딕셔너리(dict)
#
# ### list vs tuple

# %% [markdown]
# Container, Collection, List, Array

# %%
[1, 3.14, 'Tom', True]
# Out:
# [1, 3.14, 'Tom', True]

# %%
[1, 2, 3, 4, 5]
# Out:
# [1, 2, 3, 4, 5]

# %%
['apple', 'banana', 'orange']
# Out:
# ['apple', 'banana', 'orange']

# %% [markdown]
# ## 리스트의 정의
# - 빈 리스트의 정의
# - 정의와 값의 초기화

# %%
my_list = list()
my_list
# Out:
# []

# %%
my_list = []
my_list
# Out:
# []

# %%
my_list = list([1, 3, 5, 7, 9])
my_list
# Out:
# [1, 3, 5, 7, 9]

# %%
my_list = [1, 3, 5, 7, 9]
my_list
# Out:
# [1, 3, 5, 7, 9]

# %% [markdown]
# # 리스트 연산
# - 덧셈
# - 곱셈

# %% [markdown]
# ### 덧셈

# %%
[1, 3, 5] + [7, 9]
# Out:
# [1, 3, 5, 7, 9]

# %%
my = [1, 3, 5]
my
# Out:
# [1, 3, 5]

# %%
my + [7, 9]
# Out:
# [1, 3, 5, 7, 9]

# %%
"Py" + "thon"
# Out:
# 'Python'

# %% [markdown]
# ### 곱셈

# %%
[1] * 5
# Out:
# [1, 1, 1, 1, 1]

# %%
[2, 3] * 5
# Out:
# [2, 3, 2, 3, 2, 3, 2, 3, 2, 3]

# %%
[2, 3] + [2, 3] + [2, 3] + [2, 3] + [2, 3]
# Out:
# [2, 3, 2, 3, 2, 3, 2, 3, 2, 3]

# %% [markdown]
# ### 포함 (in)

# %%
my_list
# Out:
# [1, 3, 5, 7, 9]

# %%
4 in my_list
# Out:
# False

# %%
5 in my_list
# Out:
# True

# %%
my_list = []

# %%
if my_list:
  print("my_list is empty.")

# %% [markdown]
# ### 리스트의 비교

# %%
my_list = [1, 3, 5, 7, 9]

# %%
[1, 3, 5] + [7, 9] == my_list
# Out:
# True

# %%
[7, 9] + [1, 3, 5] == my_list
# Out:
# False

# %%
[7, 9] + [1, 3, 5]
# Out:
# [7, 9, 1, 3, 5]

# %% [markdown]
# ### 리스트의 길이 (len)

# %%
len(my_list)
# Out:
# 5

# %% [markdown]
# ### 리스트의 값의 접근 (인덱싱)
# - 0부터 시작
# - my_list[0]: 리스트의 첫번째 값
# - my_list[-1]: 리스트의 마지막 값
# - my_list[n]: n+1 번째 값

# %%
my_list[0]
# Out:
# 1

# %%
my_list[1]
# Out:
# 3

# %%
my_list[len(my_list)-1] # 안티패턴
# Out:
# 9

# %%
my_list[-1]
# Out:
# 9

# %% [markdown]
# ### 리스트의 슬라이싱
# - my_list[:]: 첫값부터 마지막값까지
# - my_list[n:]: n+1번째 값부터 마지막값까지
# - my_list[:m]: 첫값부터 m-1번째 값까지
# - my_list[n:m]: n+1번째 값부터 m-1번째 값까지

# %%
my_list[:]
# Out:
# [1, 3, 5, 7, 9]

# %%
my_list[:3]
# Out:
# [1, 3, 5]

# %%
my_list[1:]
# Out:
# [3, 5, 7, 9]

# %%
my_list[1:3]
# Out:
# [3, 5]

# %%
bin(75)[2:]
# Out:
# '1001011'

# %%
my_list[:] # == my_list[::1]
# Out:
# [1, 3, 5, 7, 9]

# %%
my_list[::2] # my_list[start:end:step]
# Out:
# [1, 5, 9]

# %%
my_list2 = [1, 2, 3, 4, 5, 6, 7, 8, 9]
my_list2
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
my_list2[::2]
# Out:
# [1, 3, 5, 7, 9]

# %%
my_list2[1::2]
# Out:
# [2, 4, 6, 8]

# %%
my_list2[::-1]
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1]

# %%
my_list[3:100]
# Out:
# [7, 9]

# %%
dir(my_list)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %% [markdown]
# ### 리스트의 값추가
# - **list.append()**
# - list.insert()
# - list.extend()

# %%
my_list.append?

# %%
my_list3 = []
my_list3
# Out:
# []

# %%
my_list3.append(100)
my_list3
# Out:
# [100]

# %%
my_list3.append(200)
my_list3
# Out:
# [100, 200]

# %%
my_list3.append([300, 400])
my_list3
# Out:
# [100, 200, [300, 400]]

# %%
my_list3.extend([300, 400])
my_list3
# Out:
# [100, 200, [300, 400], 300, 400, 300, 400]

# %%
my_list3.insert(0, -100)
my_list3
# Out:
# [-100, 100, 200, [300, 400], 300, 400, 300, 400]

# %% [markdown]
# ### 리스트 값 삭제
# - list.clear()
# - list.remove()
# - list.pop()
# - my_list = []

# %%
my_list3
# Out:
# [-100, 100, 200, [300, 400], 300, 400, 300, 400]

# %%
my_list4 = my_list3[:]
my_list4
# Out:
# [-100, 100, 200, [300, 400], 300, 400, 300, 400]

# %%
my_list4.remove([300, 400])

# %%
my_list4
# Out:
# [-100, 100, 200, 300, 400, 300, 400]

# %%
my_list4.remove([300, 400])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-d96bca6746c7> in <module>()
# ----> 1 my_list4.remove([300, 400])
#
# ValueError: list.remove(x): x not in list

# %%
my_list4
# Out:
# [-100, 100, 200, 300, 400, 300, 400]

# %%
my_list4.pop()
# Out:
# 400

# %%
my_list4
# Out:
# [-100, 100, 200, 300, 400, 300]

# %%
my_list4.clear()
my_list4
# Out:
# []

# %%
my_list4 = my_list3[:]
my_list4
# Out:
# [-100, 100, 200, [300, 400], 300, 400, 300, 400]

# %%
my_list4 = []
my_list4
# Out:
# []

# %% [markdown]
# ### 리스트 복제
# - list.copy()
# - my_list[:]

# %%
my_list3.remove([300, 400])

# %%
my_list5 = my_list3[::-1].copy()
my_list5
# Out:
# [400, 300, 400, 300, 200, 100, -100]

# %%
my_list6 = my_list3[::-1]
my_list6
# Out:
# [400, 300, 400, 300, 200, 100, -100]

# %% [markdown]
# ## 리스트 값의 정렬
# [3, 5, 1, 4] => [1, 3, 4, 5]
# - sorted()
# - list.sort()
# - sorted() vs list.sort()

# %%
my_list5
for n in my_list5:
  print(type(n))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
sorted(my_list5) # 정렬의 복사본을 반환
# Out:
# [-100, 100, 200, 300, 300, 400, 400]

# %%
my_list6.sort()

# %%
my_list6
# Out:
# [-100, 100, 200, 300, 300, 400, 400]

# %%
my_list5
# Out:
# [400, 300, 400, 300, 200, 100, -100]

# %%
sorted(my_list5, reverse=True)
# Out:
# [400, 400, 300, 300, 200, 100, -100]

# %%
my_list6.sort(reverse=True)
my_list6
# Out:
# [400, 400, 300, 300, 200, 100, -100]

# %% [markdown]
# ### 리스트의 역배열
# - reversed()
# - my_list.reverse()
# - my_list[::-1]

# %%
my_list5
# Out:
# [400, 300, 400, 300, 200, 100, -100]

# %%
my_list6
# Out:
# [400, 400, 300, 300, 200, 100, -100]

# %%
list(reversed(my_list5))
# Out:
# [-100, 100, 200, 300, 400, 300, 400]

# %%
my_list5.reverse()
my_list5
# Out:
# [-100, 100, 200, 300, 400, 300, 400]

# %%
my_list5[::-1]
# Out:
# [400, 300, 400, 300, 200, 100, -100]

# %%
my_list8 = [[2, 3], [1, 2], [5, 7], [-1, 9]]
sorted(my_list8)
# Out:
# [[-1, 9], [1, 2], [2, 3], [5, 7]]

# %%
my_list8 = [[2, 3], [1, 2], [5, 7], [-1, 9]]
sorted(my_list8, key=lambda elem:elem[1])
# Out:
# [[1, 2], [2, 3], [5, 7], [-1, 9]]

# %% [markdown]
# # 튜플(Tuple)

# %% [markdown]
# ## 튜플의 정의
# - 빈 튜플의 정의
# - 튜플의 정의와 초기와

# %%
my_tuple = tuple()
my_tuple
# Out:
# ()

# %%
my_tuple = ()
my_tuple
# Out:
# ()

# %%
my_tuple = tuple(list())
my_tuple
# Out:
# ()

# %%
my_tuple = (2, 4, 6, 8, 10)
my_tuple
# Out:
# (2, 4, 6, 8, 10)

# %%
my_tuple = tuple([2, 4, 6, 8, 10])
my_tuple
# Out:
# (2, 4, 6, 8, 10)

# %%
my_tuple = tuple((2, 4, 6, 8, 10))
my_tuple
# Out:
# (2, 4, 6, 8, 10)

# %%
my_tuple = 2, 4, 6, 8, 10
my_tuple
# Out:
# (2, 4, 6, 8, 10)

# %% [markdown]
# ## 튜플의 연산
# - 덧셈
# - 곱셈

# %%
(2, 4, 6) + (8, 10)
# Out:
# (2, 4, 6, 8, 10)

# %%
(2, 4, 6) + 8
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-124-10e5ae31efa8> in <module>()
# ----> 1 (2, 4, 6) + 8
#
# TypeError: can only concatenate tuple (not "int") to tuple

# %%
(2, 3) * 5
# Out:
# (2, 3, 2, 3, 2, 3, 2, 3, 2, 3)

# %%
(1) * 5
# Out:
# 5

# %%
(1, 1, 1, 1, 1)
# Out:
# (1, 1, 1, 1, 1)

# %%
(1,) * 5
# Out:
# (1, 1, 1, 1, 1)

# %%
[1] * 5
# Out:
# [1, 1, 1, 1, 1]

# %%
[1,]
# Out:
# [1]

# %% [markdown]
# ## in(포함) 연산

# %%
my_tuple
# Out:
# (2, 4, 6, 8, 10)

# %%
3 in my_tuple
# Out:
# False

# %%
4 in my_tuple
# Out:
# True

# %%
(2, 4, 6) + (8, 10) == (2, 4, 6, 8, 10)
# Out:
# True

# %%
(8, 10) + (2, 4, 6) == (2, 4, 6, 8, 10) # 순서고려
# Out:
# False

# %% [markdown]
# ## 튜플의 길이
# - len()

# %%
len(my_tuple)
# Out:
# 5

# %% [markdown]
# ## 튜플의 값 가져오기
# - my_tuple[0]: 첫번째
# - my_tuple[n]: n-1번째
# - my_tuple[-1]: 마지막

# %% [markdown]
# #### 첫번째 값

# %%
my_tuple[0]
# Out:
# 2

# %% [markdown]
# ### 마지막 값

# %%
my_tuple[-1]
# Out:
# 10

# %%
my_tuple[4] # 안티패턴
# Out:
# 10

# %%
my_tuple[len(my_tuple)-1] # 안티패턴
# Out:
# 10

# %% [markdown]
# ### n번째 값

# %%
my_tuple[2]
# Out:
# 6

# %% [markdown]
# ## 튜플의 슬라이싱
# [start:end:step]: start+1번째부터 end번째까지 step만큼 떨어진 값

# %%
my_tuple
# Out:
# (2, 4, 6, 8, 10)

# %%
my_tuple[:3]
# Out:
# (2, 4, 6)

# %%
my_tuple[2:]
# Out:
# (6, 8, 10)

# %%
my_tuple[2:3]
# Out:
# (6,)

# %%
my_tuple[:]
# Out:
# (2, 4, 6, 8, 10)

# %%
my_tuple
# Out:
# (2, 4, 6, 8, 10)

# %%
my_tuple[::2]
# Out:
# (2, 6, 10)

# %%
my_tuple[1::2]
# Out:
# (4, 8)

# %%
my_tuple[::-1]
# Out:
# (10, 8, 6, 4, 2)

# %% [markdown]
# ## 튜플의 연산

# %%
dir(my_tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
my_tuple
# Out:
# (2, 4, 6, 8, 10)

# %%
my_tuple[0] = 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-157-8a0955bcdf4d> in <module>()
# ----> 1 my_tuple[0] = 3
#
# TypeError: 'tuple' object does not support item assignment

# %%
my_list
# Out:
# [1, 3, 5, 7, 9]

# %%
my_list[0] = 100

# %%
my_list
# Out:
# [100, 3, 5, 7, 9]

# %%
(3,) + my_tuple[1:]
# Out:
# (3, 4, 6, 8, 10)

# %%
my_tuple[:2] + (100,) + my_tuple[3:]
# Out:
# (2, 4, 100, 8, 10)

# %%
my_tuple[1:]
# Out:
# (4, 6, 8, 10)

# %%
my_tuple[:2] + my_tuple[3:]
# Out:
# (2, 4, 8, 10)

# %% [markdown]
# ### 튜플 값 찾기
# - count
# - index

# %%
my_tuple
# Out:
# (2, 4, 6, 8, 10)

# %%
my_tuple.count(2)
# Out:
# 1

# %%
my_tuple.count(11)
# Out:
# 0

# %%
my_tuple.index(7)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-169-a52329c99bd9> in <module>()
# ----> 1 my_tuple.index(7)
#
# ValueError: tuple.index(x): x not in tuple

# %%
my_tuple.index(8)
# Out:
# 3

# %% [markdown]
# ### 튜플의 정렬
# - sorted

# %%
sorted(my_tuple)
# Out:
# [2, 4, 6, 8, 10]

# %%
my_tuple
# Out:
# (2, 4, 6, 8, 10)

# %%
sorted(my_tuple, reverse=True)
# Out:
# [10, 8, 6, 4, 2]

# %%
my_tuple
# Out:
# (2, 4, 6, 8, 10)

# %%
my_tuple.sort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-175-cf5b55b84aa3> in <module>()
# ----> 1 my_tuple.sort()
#
# AttributeError: 'tuple' object has no attribute 'sort'

# %% [markdown]
# # 튜플의 역순
# - reversed
# - my_tuple[::-1]

# %%
list(reversed(my_tuple))
# Out:
# [10, 8, 6, 4, 2]

# %%
my_tuple[::-1]
# Out:
# (10, 8, 6, 4, 2)

# %% [markdown]
# ## 리스트와 튜플
# - 리스트: 값을 담는 공간
# - 튜플: 어떠한 대상을 나타내는 것
#
# ## Mutable 객체 vs Immutable 개체

# %%
my_currency = ["USD", "KRW", "JPY"]
my_currency
# Out:
# ['USD', 'KRW', 'JPY']

# %%
my_currency.append("CNY")
my_currency
# Out:
# ['USD', 'KRW', 'JPY', 'CNY']

# %%
my_currency[2] = "AUD"
my_currency
# Out:
# ['USD', 'KRW', 'AUD', 'CNY']

# %%
my_st1 = (1, "A반", "철수", "남학생")
my_st1
# Out:
# (1, 'A반', '철수', '남학생')

# %%
# Out:
# (1, 'A반', '영희', '여학생')

# %%
my_tuple
# Out:
# (2, 4, 6, 8, 10)

# %%
sorted(my_tuple)
# Out:
# [2, 4, 6, 8, 10]

# %%
my_tuple
# Out:
# (2, 4, 6, 8, 10)

# %%
my_tuple2 = (1, 2, 2, 3, 4, 4, 4)
my_tuple2
# Out:
# (1, 2, 2, 3, 4, 4, 4)

# %%
my_tuple2.count(2)
# Out:
# 2

# %%
my_tuple2.count(4)
# Out:
# 3

# %%
def sum_mult(a, b):
  return (a+b, a*b)

# %%
sum_mult(10, 20)
# Out:
# (30, 200)

# %%
my_tuple
# Out:
# (2, 4, 6, 8, 10)

# %%
a, b, c, d, _ = my_tuple

# %%
a
# Out:
# 2

# %%
b
# Out:
# 4

# %%
c
# Out:
# 6

# %%
a, b = sum_mult(10, 20)

# %%
a
# Out:
# 30

# %%
b
# Out:
# 200

# %%
(a, b) = sum_mult(10, 20)

# %%
a
# Out:
# 30

# %%
b
# Out:
# 200

# %%
c = sum_mult(10, 20)

# %%
c[0]
# Out:
# 30

# %%
c[-1]
# Out:
# 200

# %% [markdown]
# ## 딕셔너리(dict)
# - 키-값 저장공간

# %% [markdown]
# 딕셔너리의 정의
# - 빈 dict 정의
# - dict의 정의와 초기화

# %%
my_dict = dict()
my_dict
# Out:
# {}

# %%
my_dict = {}
my_dict
# Out:
# {}

# %%
my_dict = dict({
    "a": 30,
    "b": 40,
    "c": 50,
})
my_dict
# Out:
# {'a': 30, 'b': 40, 'c': 50}

# %%
my_dict = {
    "a": 30,
    "b": 40,
    "c": 50
}
my_dict
# Out:
# {'a': 30, 'b': 40, 'c': 50}

# %%
my_dict = dict(
    a=30,
    b=40,
    c=50
)
my_dict
# Out:
# {'a': 30, 'b': 40, 'c': 50}

# %% [markdown]
# ## dict의 연산
# - 값의 추가
# - 값의 접근
# - 값의 변경
# - 값의 삭제
# - 키의 포함

# %%
my_dict = {}

# %%
my_dict
# Out:
# {}

# %%
my_dict['a'] = 100

# %%
my_dict
# Out:
# {'a': 100}

# %%
my_dict['a'] = 200
my_dict
# Out:
# {'a': 200}

# %%
my_dict['a']
# Out:
# 200

# %%
my_dict['b']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-231-c1dc5a2b76cc> in <module>()
# ----> 1 my_dict['b']
#
# KeyError: 'b'

# %%
my_dict.get('a')
# Out:
# 200

# %%
print(my_dict.get('b'))
# Out:
# None

# %%
my_dict.get('b', -1)
# Out:
# -1

# %%
my_dict.get('b', 0)
# Out:
# 0

# %%
my_dict['a'] = 100
my_dict['b'] = 200
my_dict['c'] = 300
my_dict
# Out:
# {'a': 100, 'b': 200, 'c': 300}

# %%
del my_dict['b']
my_dict
# Out:
# {'a': 100}

# %%
my_dict.update({
    'b': -200,
    'd': 400
})
my_dict
# Out:
# {'a': 100, 'b': -200, 'c': 300, 'd': 400}

# %% [markdown]
# ### 키값 포함(in)

# %%
my_dict['f']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-241-939b9ab9148a> in <module>()
# ----> 1 my_dict['f']
#
# KeyError: 'f'

# %%
'f' in my_dict
# Out:
# False

# %%
'a' in my_dict # 안티패턴
# Out:
# True

# %%
'a' in my_dict.keys()
# Out:
# True

# %%
100 in my_dict.values()
# Out:
# True

# %%
my = list([2, 3, 4])

# %%
my_dict.items()
# Out:
# dict_items([('a', 100), ('b', -200), ('c', 300), ('d', 400)])

# %%
for k, v in my_dict.items():
  print(f"key={k}, value={v}")
# Out:
# key=a, value=100
# key=b, value=-200
# key=c, value=300
# key=d, value=400

# %%
my_dict.copy()
# Out:
# {'a': 100, 'b': -200, 'c': 300, 'd': 400}

# %%
my_dict[:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-255-98f1315e97f5> in <module>()
# ----> 1 my_dict[:]
#
# TypeError: unhashable type: 'slice'

# %% [markdown]
# ### 리스트의 복사
# - my_list.copy
# - my_list[::]

# %%
my_list
# Out:
# [100, 3, 5, 7, 9]

# %%
my_list2 = my_list
my_list2
# Out:
# [100, 3, 5, 7, 9]

# %%
my_list3 = my_list[::]
my_list3
# Out:
# [100, 3, 5, 7, 9]

# %%
my_list[2] = 25000
my_list
# Out:
# [100, 3, 25000, 7, 9]

# %%
my_list2
# Out:
# [100, 3, 25000, 7, 9]

# %%
my_list3
# Out:
# [100, 3, 5, 7, 9]

# %%
bin(75)
# Out:
# '0b1001011'

# %%
my_list = list('ABCDEFG')
my_present = [int(c) for c in bin(75)[2:]]

# %%
my_list
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
my_present
# Out:
# [1, 0, 0, 1, 0, 1, 1]

# %%
from itertools import compress
list(compress(my_list, my_present))
# Out:
# ['A', 'D', 'F', 'G']

# %% [markdown]
# https://pacientes.github.io/posts/2021/01/algorithm_programmers_17687/

# %% [markdown]
# 3,  5문제
# 상, 중, 하
# - 쉽다. 중2, 하1
# - 어렵다: 상1, 중2
# - 문제 갯수
# - 1(상), 2, 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
my_str = "1"

# %%
my_str.zfill(3)
# Out:
# '001'

# %%
"{0:010d}".format(3)
# Out:
# '0000000003'

# %%
my_str.rjust(3, ' ')
# Out:
# '  1'

# %%
my_str1 = '*'
my_str2 = '**'
print(my_str1.rjust(5, ' '))
print(my_str2.rjust(5, ' '))
# Out:
#     *
#    **

# %%
' ' * 3 + '*' * 2
# Out:
# '   **'

# %%
dir(my_str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
# 1000개 feature
