# %% [markdown]
# # 변수
# - 값을 저장하는 공간 (Space)
# - 동적 타입핑 (Python, Javascript) <=> 정적 타입핑 (C/C++, Java)
#
# ## 변수의 정의와 선언
# ## type과 isinstance
# ## 명시적 형변환
# ## 전역변수와 지역변수

# %%
a = "Hello"

# %%
type(a)
# Out:
# str

# %%
int(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-8b2ab3991dae> in <module>()
# ----> 1 int(a)
#
# ValueError: invalid literal for int() with base 10: 'Hello'

# %% [markdown]
# 변수
# - 숫자(number)
#   - 정수형 (int)
#   - 실수형 (float)
# - 불리언(boolean)
# - 문자열(string)

# %%
a = 3

# %%
a + 1
# Out:
# 4

# %%
b = 3.17
b
# Out:
# 3.17

# %%
b = a / 7
b
# Out:
# 0.42857142857142855

# %%
b = a * 1.0
b
# Out:
# 3.0

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
isinstance(a, int)
# Out:
# True

# %%
isinstance(a, float)
# Out:
# False

# %%
isinstance(b, float)
# Out:
# True

# %%
isinstance(b, float)
# Out:
# True

# %% [markdown]
# ## Class V.S. Instance
# ## Type V.S. Memory

# %%
class Dog:
  name: str
  sound: str

# %%
doga = Dog()
doga.name = "a"

# %%
doga.name
# Out:
# 'a'

# %%
dogb = Dog()
dogb.name = "b"

# %%
dogb
# Out:
# 'b'

# %%
my_str2021 = "hello"
my_str2021
# Out:
# 'hello'

# %%
def fn():
  my_str2021 = "world"
  return my_str2021

# %%
my_str2021
# Out:
# 'hello'

# %%
fn()
# Out:
# 'world'

# %%
my_str2021
# Out:
# 'hello'

# %%
def fn():
  global my_str2021
  my_str2021 = "world"
  return my_str2021

# %%
my_str2021
# Out:
# 'hello'

# %%
fn()
# Out:
# 'world'

# %%
my_str2021
# Out:
# 'world'

# %%
def fn2():
  globals()['my_str2021'] = 'hello' 
  return globals()['my_str2021']

# %%
my_str2021
# Out:
# 'world'

# %%
fn2()
# Out:
# 'hello'

# %%
my_str2021
# Out:
# 'hello'
