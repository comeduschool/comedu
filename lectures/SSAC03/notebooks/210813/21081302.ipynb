# %% [markdown]
# # 문자열(String)
#
# > 정의
# >
# > 0개 이상의 문자(character)의 집합, 배열
# >
# > 따옴표('), 큰 따옴표(")로 정의

# %%
"Hello, world"
# Out:
# 'Hello, world'

# %%
'Hello, world'
# Out:
# 'Hello, world'

# %%
"" # Empty String
# Out:
# ''

# %%
'' # Empty String
# Out:
# ''

# %% [markdown]
# ## 문자열 상수

# %%
import string

# %%
string.ascii_letters
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
string.ascii_uppercase
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
string.ascii_lowercase + string.ascii_uppercase
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
string.digits
# Out:
# '0123456789'

# %%
string.hexdigits
# Out:
# '0123456789abcdefABCDEF'

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
string.whitespace
# Out:
# ' \t\n\r\x0b\x0c'

# %% [markdown]
# ## 이스케이핑 (Escaping)
#
# 키보드에 없는 문자 또는 문자열로 표현할 수 없는 것들을 표현하기 위한 표현식.
#
# ![escaping.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("a\tb")
# Out:
# a	b

# %%
print("a       b")
# Out:
# a       b

# %%
print("\\t == 탭")
# Out:
# \t == 탭

# %%
print("\"Hello\"")
# Out:
# "Hello"

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# # Raw String

# %%
print("C:\some\name")
# Out:
# C:\some
# ame

# %%
print("Hello, \nBTS!")
# Out:
# Hello,
# BTS!

# %%
print(r"C:\some\name") # raw
# Out:
# C:\some\name

# %%
print(r"\t")
# Out:
# \t

# %% [markdown]
# 멀티라인(Multi) 문자열

# %%
print("""
첫 큰 따옴표 세개는 주석의 시작을 나타냅니다.
이렇게 자유롭게 주석을 작성한 후에 
    주석이 끝난 부분에 아래처럼 큰 따옴표 세개를 다시 작성하면
주석의 끝을 나타내게 됩니다.


출처: https://blockdmask.tistory.com/376 [개발자 지망생]
""")
# Out:
# 첫 큰 따옴표 세개는 주석의 시작을 나타냅니다.
# 이렇게 자유롭게 주석을 작성한 후에
#   주석이 끝난 부분에 아래처럼 큰 따옴표 세개를 다시 작성하면
# 주석의 끝을 나타내게 됩니다.
#
#
# 출처: https://blockdmask.tistory.com/376 [개발자 지망생]

# %%
print("첫 큰 따옴표 세개는 주석의 시작을 나타냅니다.\n이렇게 자유롭게 주석을 작성한 후에 \n\t주석이 끝난 부분에 아래처럼 큰 따옴표 세개를 다시 작성하면\n주석의 끝을 나타내게 됩니다.")
# Out:
# 첫 큰 따옴표 세개는 주석의 시작을 나타냅니다.
# 이렇게 자유롭게 주석을 작성한 후에
# 	주석이 끝난 부분에 아래처럼 큰 따옴표 세개를 다시 작성하면
# 주석의 끝을 나타내게 됩니다.

# %% [markdown]
# ### 문자열의 연산
# - 덧셈
# - 곱셈
# - 포함 (in)
# - 비교 (==)

# %% [markdown]
# #### 덧셈

# %%
"Hello, " + "world"
# Out:
# 'Hello, world'

# %% [markdown]
# #### 곱셈

# %%
"Hello " * 3
# Out:
# 'Hello Hello Hello '

# %%
"Hello " + "Hello " + "Hello "
# Out:
# 'Hello Hello Hello '

# %%
"Hello" * 0
# Out:
# ''

# %% [markdown]
# #### 포함

# %%
"H" in "Hello"
# Out:
# True

# %%
"h" in "Hello"
# Out:
# False

# %%
"He" in "Hello"
# Out:
# True

# %%
"ll" in "Hello"
# Out:
# True

# %%
"" in "Hello"
# Out:
# True

# %% [markdown]
# #### 비교 (==)

# %%
"Hello" == "Hello"
# Out:
# True

# %%
"hello" == "Hello"
# Out:
# False

# %% [markdown]
# ## 문자열의 인덱싱/슬라이싱
# - dict형식의 표현([])
# - [0]: 첫번째 문자
# - [-1]: 마지막 문자

# %%
my_str = "Python"
my_str
# Out:
# 'Python'

# %% [markdown]
# ### 인덱싱

# %%
my_str[0]
# Out:
# 'P'

# %%
my_str[-1]
# Out:
# 'n'

# %%
my_str[3]
# Out:
# 'h'

# %% [markdown]
# ### 슬라이싱

# %%
my_str[:2]
# Out:
# 'Py'

# %%
my_str[2:]
# Out:
# 'thon'

# %%
my_str[1:3]
# Out:
# 'yt'

# %%
my_str[:]
# Out:
# 'Python'

# %%
my_str[::-1]
# Out:
# 'nohtyP'

# %%
my_str[::2]
# Out:
# 'Pto'

# %%
my_str[1::2]
# Out:
# 'yhn'

# %% [markdown]
# ### 문자열의 길이
# - len

# %%
len(my_str)
# Out:
# 6

# %%
my_str1 = "      Python     "
my_str1
# Out:
# '      Python     '

# %%
len(my_str1)
# Out:
# 17

# %%
len(my_str1.strip())
# Out:
# 6

# %%
my_str1.strip()
# Out:
# 'Python'

# %%
string.whitespace
# Out:
# ' \t\n\r\x0b\x0c'

# %%
my_str2 = "      Pyt   hon     "
my_str2
# Out:
# '      Pyt   hon     '

# %%
my_str2.strip()
# Out:
# 'Pyt   hon'

# %%
my_str2.rstrip()
# Out:
# '      Pyt   hon'

# %%
my_str2.lstrip()
# Out:
# 'Pyt   hon     '

# %% [markdown]
# ## 문자열의 메소드
# - 문자 찾기
# - 접두사와 접미사
# - 문자열 변경1
# - 공백 제거하기
# - 문자열 변경2
# - 인코딩

# %%
my_str = "Python"

# %%
dir(my_str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %% [markdown]
# ### 문자열 찾기
#
# - find
#   찾음: 위치(index)
#   못찾음: -1
#
# - count
# - index
#   찾음: 위치(index)
#   못찾음: 에러 (프로그램)

# %%
my_str.find("n")
# Out:
# 5

# %%
my_str
# Out:
# 'Python'

# %%
my_str.find("t")
# Out:
# 2

# %%
my_str.find("z")
# Out:
# -1

# %%
my_str.index("t")
# Out:
# 2

# %%
my_str.index("z")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-b6f1fb491c46> in <module>()
# ----> 1 my_str.index("z")
#
# ValueError: substring not found

# %%
print(my_str.find("z"))
print("next!")
# Out:
# -1
# next!

# %%
print(my_str.index("z"))
print("next!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-65b3882faa73> in <module>()
# ----> 1 print(my_str.index("z"))
#       2 print("next!")
#
# ValueError: substring not found

# %%
my_str.count("t")
# Out:
# 1

# %%
my_str.count("z")
# Out:
# 0

# %%
my_str.count("Py")
# Out:
# 1

# %%
my_str.find("Py")
# Out:
# 0

# %% [markdown]
# ### 접두사와 접미사
#
# - startswith
# - endswith
#
# e.g. [학생]유정환, 과제_날짜_유정환, 날짜_이름_과제

# %%
my_str.startswith("P")
# Out:
# True

# %%
my_str.startswith("Py")
# Out:
# True

# %%
my_str.endswith("n")
# Out:
# True

# %%
my_str.endswith("on")
# Out:
# True

# %%
naver = "http://www.naver.com" # ftp://, https://, smpt://

# %%
naver.startswith("http://")
# Out:
# True

# %%
naver.endswith("com")
# Out:
# True

# %%
naver.endswith("co.kr")
# Out:
# False

# %%
jumin = "2XXXXXXX" # Female
jumin
# Out:
# '2XXXXXXX'

# %%
jumin.startswith("1") # 1 / 3
# Out:
# False

# %%
jumin.startswith("2") # 2 / 4
# Out:
# True

# %%
jumin.find("1") == 0
# Out:
# False

# %%
jumin.find("2") == 0
# Out:
# True

# %%
my_str.startswith("Python")
# Out:
# True

# %% [markdown]
# ### 소문자, 대문자 변경
# - lower()
# - uppper()
# - capitalize()

# %%
my_str1 = "hello, World!"
my_str1
# Out:
# 'hello, World!'

# %%
my_str1.upper()
# Out:
# 'HELLO, WORLD!'

# %%
my_str1.lower()
# Out:
# 'hello, world!'

# %%
my_str1.capitalize()
# Out:
# 'Hello, world!'

# %% [markdown]
# #### capitalize vs upper() + lower()

# %%
my_str1.capitalize() == my_str1[0].upper() + my_str1[1:].lower()
# Out:
# True

# %% [markdown]
#  ### 공백 제거하기
#  - strip
#  - rstrip
#  - lstrip
#  - replace (중요)

# %%
my_str2 = "       Pyt    hon         "
my_str2
# Out:
# '       Pyt    hon         '

# %%
my_str2.strip()
# Out:
# 'Pyt    hon'

# %%
my_str2.rstrip()
# Out:
# '       Pyt    hon'

# %%
my_str2.lstrip()
# Out:
# 'Pyt    hon         '

# %%
my_str2.strip() == my_str2.rstrip().lstrip() # == my_str2.lstrip().rstrip()
# Out:
# True

# %%
my_str2.replace(" ", "")
# Out:
# 'Python'

# %%
my_str3 = "    Hello, world!     "
my_str3.replace(" ", "")
# Out:
# 'Hello,world!'

# %%
my_str3.strip()
# Out:
# 'Hello, world!'

# %%
my_str4 = " P y t h o n "
my_str4
# Out:
# ' P y t h o n '

# %%
my_str4.replace(" " ,"", 3)
# Out:
# 'Pyt h o n '

# %%
my_str4.replace("P", "C")
# Out:
# ' C y t h o n '

# %%
"abbcaaba".replace("a", "z")
# Out:
# 'zbbczzbz'
