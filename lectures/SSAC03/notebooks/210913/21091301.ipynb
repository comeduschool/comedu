# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Text(String) type
# - \n
# - object
# - pandas.StringDtype

# %% [markdown]
# # 타입 명시 방법
# - Series/DataFrame
# - astype

# %%
my_ss = pd.Series(list("abc"*1000))
my_ss
# Out:
# 0       a
# 1       b
# 2       c
# 3       a
# 4       b
#        ..
# 2995    b
# 2996    c
# 2997    a
# 2998    b
# 2999    c
# Length: 3000, dtype: object

# %%
my_ss.dtype # object / 'O' => str => 여러타입이 섞여 있을 수 있다.
# Out:
# dtype('O')

# %%
my_ss = pd.Series(list("abc"), dtype="string")
my_ss
# Out:
# 0    a
# 1    b
# 2    c
# dtype: string

# %%
my_ss = pd.Series(list("abc"), dtype=pd.StringDtype())
my_ss
# Out:
# 0    a
# 1    b
# 2    c
# dtype: string

# %%
my_ss = pd.Series(list("abc"))
my_ss
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
my_ss.dtype
# Out:
# dtype('O')

# %%
my_ss1 = my_ss.astype("string")
my_ss1
# Out:
# 0    a
# 1    b
# 2    c
# dtype: string

# %%
my_ss1.dtype
# Out:
# StringDtype

# %%
my_ss1 = my_ss.astype(pd.StringDtype())
my_ss1
# Out:
# 0    a
# 1    b
# 2    c
# dtype: string

# %%
my_ss1.dtype
# Out:
# StringDtype

# %% [markdown]
# # String과 다른타입
# - 3.14 => "3.14"
# - 3 => "3"
# - "3a" => X
# - "3+4i" => X

# %%
my_ss1 = pd.Series(["Hello, World", 2, np.nan], dtype="string")
my_ss1
# Out:
# 0    Hello, World
# 1               2
# 2            <NA>
# dtype: string

# %%
my_ss1.iloc[1]
# Out:
# '2'

# %%
type(my_ss1.iloc[2])
# Out:
# pandas._libs.missing.NAType

# %% [markdown]
# # 문자열 메소드
# - 파이썬의 문자열 메소드와 비슷한 동작
# - 각각에 데이터에 적용

# %%
my_list = ["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"]
my_list
# Out:
# ['A', 'B', 'C', 'Aaba', 'Baca', nan, 'CABA', 'dog', 'cat']

# %%
my_ss2 = pd.Series(my_list, dtype="string")
my_ss2
# Out:
# 0       A
# 1       B
# 2       C
# 3    Aaba
# 4    Baca
# 5    <NA>
# 6    CABA
# 7     dog
# 8     cat
# dtype: string

# %%
"Hello, PYTHON".lower()
# Out:
# 'hello, python'

# %%
my_ss2.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5    <NA>
# 6    caba
# 7     dog
# 8     cat
# dtype: string

# %%
my_ss2.str.upper()
# Out:
# 0       A
# 1       B
# 2       C
# 3    AABA
# 4    BACA
# 5    <NA>
# 6    CABA
# 7     DOG
# 8     CAT
# dtype: string

# %%
len("Hello, World!")
# Out:
# 13

# %%
my_ss2.str.len()
# Out:
# 0       1
# 1       1
# 2       1
# 3       4
# 4       4
# 5    <NA>
# 6       4
# 7       3
# 8       3
# dtype: Int64

# %%
my_list1 = [' jack   ', 'jill   ', '      jesse', 'frank']
my_list1
# Out:
# [' jack   ', 'jill   ', '      jesse', 'frank']

# %%
my_ss3 = pd.Series(my_list1, dtype="string")
my_ss3
# Out:
# 0        jack
# 1        jill
# 2          jesse
# 3          frank
# dtype: string

# %%
my_ss3.str.rstrip()
# Out:
# 0           jack
# 1           jill
# 2          jesse
# 3          frank
# dtype: string

# %%
my_ss3.str.lstrip()
# Out:
# 0    jack
# 1    jill
# 2      jesse
# 3      frank
# dtype: string

# %%
my_ss3.str.lstrip().str.rstrip()
# Out:
# 0     jack
# 1     jill
# 2    jesse
# 3    frank
# dtype: string

# %%
my_ss3.str.strip()
# Out:
# 0     jack
# 1     jill
# 2    jesse
# 3    frank
# dtype: string

# %%
my_index = pd.Index(my_list1, dtype="string")
my_index
# Out:
# Index([' jack   ', 'jill   ', '      jesse', 'frank'], dtype='object')

# %%
my_index.str.rstrip()
# Out:
# Index([' jack', 'jill', '      jesse', 'frank'], dtype='object')

# %%
my_index.str.lstrip()
# Out:
# Index(['jack   ', 'jill   ', 'jesse', 'frank'], dtype='object')

# %%
my_index.str.strip()
# Out:
# Index(['jack', 'jill', 'jesse', 'frank'], dtype='object')

# %%
my_df = pd.DataFrame(np.random.randn(100,2), columns=[" Column A ", " Column  B  "])
my_df
# Out:
#      Column A    Column  B
# 0    -0.968915      0.792180
# 1    -0.299541      0.948784
# 2    -0.161645      0.671939
# 3     1.480244     -1.583668
# 4    -0.056561     -0.300390
# ..         ...           ...
# 95   -0.428141      0.092884
# 96   -1.463383     -0.366394
# 97    0.210684      1.022058
# 98   -0.403480      0.561599
# 99   -0.657454      0.019764
#
# [100 rows x 2 columns]

# %%
my_df[" Column A "]
# Out:
# 0    -0.968915
# 1    -0.299541
# 2    -0.161645
# 3     1.480244
# 4    -0.056561
#         ...
# 95   -0.428141
# 96   -1.463383
# 97    0.210684
# 98   -0.403480
# 99   -0.657454
# Name:  Column A , Length: 100, dtype: float64

# %%
my_columns = my_df.columns.str.strip()
my_columns
# Out:
# Index(['Column A', 'Column  B'], dtype='object')

# %%
my_columns1 = my_columns.str.lower()
my_columns1
# Out:
# Index(['column a', 'column  b'], dtype='object')

# %%
my_columns2 = my_columns1.str.replace(" ", "_")
my_columns2
# Out:
# Index(['column_a', 'column__b'], dtype='object')

# %%
my_columns3 = my_columns2.str.replace("__", "_")
my_columns3
# Out:
# Index(['column_a', 'column_b'], dtype='object')

# %%
my_df.columns.str.strip().str.lower().str.replace(" ", "_")
# Out:
# Index(['column_a', 'column_b'], dtype='object')

# %%
my_df.columns = my_columns3
my_df
# Out:
#     column_a  column_b
# 0  -0.968915  0.792180
# 1  -0.299541  0.948784
# 2  -0.161645  0.671939
# 3   1.480244 -1.583668
# 4  -0.056561 -0.300390
# ..       ...       ...
# 95 -0.428141  0.092884
# 96 -1.463383 -0.366394
# 97  0.210684  1.022058
# 98 -0.403480  0.561599
# 99 -0.657454  0.019764
#
# [100 rows x 2 columns]

# %%
my_df['column_a']
# Out:
# 0    -0.968915
# 1    -0.299541
# 2    -0.161645
# 3     1.480244
# 4    -0.056561
#         ...
# 95   -0.428141
# 96   -1.463383
# 97    0.210684
# 98   -0.403480
# 99   -0.657454
# Name: column_a, Length: 100, dtype: float64

# %%
my_df.column_a
# Out:
# 0    -0.968915
# 1    -0.299541
# 2    -0.161645
# 3     1.480244
# 4    -0.056561
#         ...
# 95   -0.428141
# 96   -1.463383
# 97    0.210684
# 98   -0.403480
# 99   -0.657454
# Name: column_a, Length: 100, dtype: float64

# %%
my_ss = pd.Series(['a,b,c', 'c,d,e', np.nan, 'f,g,h'], dtype="string")
my_ss
# Out:
# 0    a,b,c
# 1    c,d,e
# 2     <NA>
# 3    f,g,h
# dtype: string

# %%
my_ss.str.split(",")
# Out:
# 0    [a, b, c]
# 1    [c, d, e]
# 2         <NA>
# 3    [f, g, h]
# dtype: object

# %%
my_ss.str.split(",").str[1]
# Out:
# 0       b
# 1       d
# 2    <NA>
# 3       g
# dtype: object

# %%
my_ss.str.split(",").str.get(1)
# Out:
# 0       b
# 1       d
# 2    <NA>
# 3       g
# dtype: object

# %%
my_ss.str.split(",").str.get(100)
# Out:
# 0     NaN
# 1     NaN
# 2    <NA>
# 3     NaN
# dtype: object

# %%
my_df2 = my_ss.str.split(",", expand=True)
my_df2.columns=["first", "second", "third"]
my_df2
# Out:
#   first second third
# 0     a      b     c
# 1     c      d     e
# 2  <NA>   <NA>  <NA>
# 3     f      g     h

# %%
my_df2[0]
# Out:
# 0       a
# 1       c
# 2    <NA>
# 3       f
# Name: 0, dtype: string

# %%
my_df2.loc[:, 0]
# Out:
# 0       a
# 1       c
# 2    <NA>
# 3       f
# Name: 0, dtype: string

# %%
my_df2.iloc[:, 0]
# Out:
# 0       a
# 1       c
# 2    <NA>
# 3       f
# Name: 0, dtype: string

# %%
my_df2.first
# Out:
# <bound method NDFrame.first of   first second third
# 0     a      b     c
# 1     c      d     e
# 2  <NA>   <NA>  <NA>
# 3     f      g     h>

# %%
my_df2['first']
# Out:
# 0       a
# 1       c
# 2    <NA>
# 3       f
# Name: first, dtype: string

# %%
my_df2.loc[:, 'first']
# Out:
# 0       a
# 1       c
# 2    <NA>
# 3       f
# Name: first, dtype: string

# %%
my_ss.str.split(",", expand=True, n=1)
# Out:
#       0     1
# 0     a   b,c
# 1     c   d,e
# 2  <NA>  <NA>
# 3     f   g,h

# %%
my_ss.str.rsplit(",", expand=True, n=1)
# Out:
#       0     1
# 0   a,b     c
# 1   c,d     e
# 2  <NA>  <NA>
# 3   f,g     h

# %%
"Python".replace("P", "C")
# Out:
# 'Cython'

# %%
my_list
# Out:
# ['A', 'B', 'C', 'Aaba', 'Baca', nan, 'CABA', 'dog', 'cat']

# %%
my_ss = pd.Series(my_list, dtype="string")
my_ss
# Out:
# 0       A
# 1       B
# 2       C
# 3    Aaba
# 4    Baca
# 5    <NA>
# 6    CABA
# 7     dog
# 8     cat
# dtype: string

# %%
my_ss.str.replace("^.o", "O", regex=True)
# Out:
# 0       A
# 1       B
# 2       C
# 3    Aaba
# 4    Baca
# 5    <NA>
# 6    CABA
# 7      Og
# 8     cat
# dtype: string

# %%
my_ss = pd.Series(['a', 'b', 'c', 'd'], dtype="string")
my_ss
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: string

# %%
my_ss.str.cat()
# Out:
# 'abcd'

# %%
my_ss.str.cat(sep='_')
# Out:
# 'a_b_c_d'

# %%
my_ss.str.cat(sep="$")
# Out:
# 'a$b$c$d'

# %%
my_ss = pd.Series(['a', 'b', np.nan, 'd'], dtype="string")
my_ss
# Out:
# 0       a
# 1       b
# 2    <NA>
# 3       d
# dtype: string

# %%
my_ss.str.cat()
# Out:
# 'abd'

# %%
my_ss.str.cat(sep=";")
# Out:
# 'a;b;d'

# %%
my_ss.str.cat(sep=":", na_rep="NOOOO")
# Out:
# 'a:b:NOOOO:d'

# %%
my_list2 = ["d", "c", "b", "a"]

# %%
my_ss1 = pd.Series(list("abcd"), dtype="string")
my_ss1
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: string

# %%
my_ss.str.cat(["d", "c", "b", "a"])
# Out:
# 0      ad
# 1      bc
# 2    <NA>
# 3      da
# dtype: string

# %%
my_ss.str.cat(my_ss1)
# Out:
# 0      aa
# 1      bb
# 2    <NA>
# 3      dd
# dtype: string

# %%
my_ss.str.cat(my_ss1, na_rep="X")
# Out:
# 0    aa
# 1    bb
# 2    Xc
# 3    dd
# dtype: string

# %%
my_df5 = pd.DataFrame({"a": my_ss.values, "b": my_ss1.values}, dtype="string")

# %%
my_df5
# Out:
#       a  b
# 0     a  a
# 1     b  b
# 2  <NA>  c
# 3     d  d

# %%
my_ss.str.cat(my_df5, na_rep="X")
# Out:
# 0    aaa
# 1    bbb
# 2    XXc
# 3    ddd
# dtype: string

# %%
my_ss.index = ["x", "y", "z", "w"]
my_ss
# Out:
# x       a
# y       b
# z    <NA>
# w       d
# dtype: string

# %%
my_ss1.index = ["x", "w", "z", "y"]
my_ss1
# Out:
# x    a
# w    b
# z    c
# y    d
# dtype: string

# %%
my_ss.str.cat(my_ss1)
# Out:
# x      aa
# y      bd
# z    <NA>
# w      db
# dtype: string

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# index alignment
my_ss.str.cat(my_ss1, join='right') # left, right, inner
# Out:
# x      aa
# w      db
# z    <NA>
# y      bd
# dtype: string

# %%
my_ss.str.cat()
# Out:
# 'abd'

# %%
my_ss
# Out:
# x       a
# y       b
# z    <NA>
# w       d
# dtype: string

# %%
my_ss1.sort_index()
# Out:
# w    b
# x    a
# y    d
# z    c
# dtype: string

# %%
my_ss.str.cat(my_ss1, join='left', na_rep="X")
# Out:
# x    aa
# y    bd
# z    Xc
# w    db
# dtype: string

# %%
my_ss.str.cat(my_ss1, join='right', na_rep="X")
# Out:
# x    aa
# w    db
# z    Xc
# y    bd
# dtype: string

# %%
my_ss1.str.cat(my_ss)
# Out:
# x      aa
# w      bd
# z    <NA>
# y      db
# dtype: string

# %%
my_ss.str.cat?

# %%
my_ss1
# Out:
# x    a
# w    b
# z    c
# y    d
# dtype: string

# %%
my_ss
# Out:
# x       a
# y       b
# z    <NA>
# w       d
# dtype: string

# %%
my_ss2
# Out:
# 0       A
# 1       B
# 2       C
# 3    Aaba
# 4    Baca
# 5    <NA>
# 6    CABA
# 7     dog
# 8     cat
# dtype: string

# %%
my_ss2.str[0]
# Out:
# 0       A
# 1       B
# 2       C
# 3       A
# 4       B
# 5    <NA>
# 6       C
# 7       d
# 8       c
# dtype: string

# %%
my_ss2.str[1]
# Out:
# 0    <NA>
# 1    <NA>
# 2    <NA>
# 3       a
# 4       a
# 5    <NA>
# 6       A
# 7       o
# 8       a
# dtype: string

# %%
my_ss2.str[100]
# Out:
# 0    <NA>
# 1    <NA>
# 2    <NA>
# 3    <NA>
# 4    <NA>
# 5    <NA>
# 6    <NA>
# 7    <NA>
# 8    <NA>
# dtype: string

# %%
my_ss2
# Out:
# 0       A
# 1       B
# 2       C
# 3    Aaba
# 4    Baca
# 5    <NA>
# 6    CABA
# 7     dog
# 8     cat
# dtype: string

# %%
my_ss2.str.get(1)
# Out:
# 0    <NA>
# 1    <NA>
# 2    <NA>
# 3       a
# 4       a
# 5    <NA>
# 6       A
# 7       o
# 8       a
# dtype: string
