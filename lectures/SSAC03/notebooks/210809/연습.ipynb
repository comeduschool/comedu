# %%
# notebook / 콜랩페이지 / 콜랩

# %%
# 두번째 셀(cell)
# 셀 실행: shift + tab

# %%
# 셀 추가 / 지우기
# Mac
# cmd + m + a (append)
# cmd + m + d 
# cmd + m + b (backward)
# cmd + m + m: 코드 셀 -> 텍스트 셀
# cmd + m + m: 코드 셀 -> 텍스트 셀

# Win
# window key + m + a (append)
# window key + m + d 
# window key + m + b (backward)
# window key + m + m: 코드 셀 -> 텍스트 셀
# window key + m + y: 텍스트 셀 -> 코드 셀

# %% [markdown]
# # Markdown

# %% [markdown]
# # Title
# ## subtitle
# ###

# %% [markdown]
# # title 2
# ## 2개
# ### 3개
# #### 4개
# - 첫번쨰 항목
# - 두번쨰 항목
# -----------------------------------------
# #### 마커
# * 첫번쨰 항목
# * 두번쨰 항목
#
# #### 마커
# 1. 첫번쨰 항목
# 2. 두번째 항목

# %% [markdown]
# **볼드**
#
# [링크제목](https://www.naver.com)
#
# ```javascript
# console.log("hello")
# ```
#
# ```
# ```
#
# > Notice
# > 주의
# >> Python은 버전 3을 쓰는 것이 좋다.

# %% [markdown]
# - github / gitlab

# %%
with open("test.txt", 'w') as f:
  for i in range(10):
    f.write(f"{i}")

# %% [markdown]
# ---

# %%
import requests

# %%
import pandas as pd

# %%
import tensorflow

# %%
import numpy

# %%
# !pip install requests

# %%
# !ls
# Out:
# drive  sample_data

# %%
# !ls /
# Out:
# bin	 datalab  home	 lib64	opt   run   sys		       tools
# boot	 dev	  lib	 media	proc  sbin  tensorflow-1.15.2  usr
# content  etc	  lib32  mnt	root  srv   tmp		       var

# %%
print("Hello")
# Out:
# Hello

# %%
print("Hello")
# Out:
#   File "<ipython-input-9-79acc1463eef>", line 1
#     1 print("Hello")
#           ^
# SyntaxError: invalid syntax

# %%
dddfjdkfffddf

# %%
print("Hello, World!")
print("Hello, World!")
print("Hello, World!")
print("Hello, World!")
print("Hello, World!")
print("Hello, World!")

# %%
# local -> tensorflow 설치
# anaconda 설치
# conda tensorflow[-gpu]
# 단축키
# 여러줄 선택: alt+ctrl
# 단어선택: ctrl + d
