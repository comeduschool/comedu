# %% [markdown]
# - pandas.Series
# - pandas.DataFrame
#
# - 숫자
# - StringDtype
# - CategoricalDtype

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Categorical Data
# - 제한(유한), 공
#   - 성별, 사회계급, 혈액형, 소속,
#   - 순서 O/X
#     - 청년/장년/노년
#     - 고학년,저학년

# %%
my_ss = pd.Series(list('abcd'), dtype='category')
my_ss
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: category
# Categories (4, object): ['a', 'b', 'c', 'd']

# %%
my_ss.dtype
# Out:
# CategoricalDtype(categories=['a', 'b', 'c', 'd'], ordered=False)

# %%
my_ss = pd.Series(np.random.randint(0, 100, 20))
my_ss
# Out:
# 0     90
# 1     13
# 2     20
# 3     21
# 4      6
# 5     78
# 6     28
# 7     50
# 8     79
# 9     90
# 10    69
# 11    43
# 12    37
# 13    60
# 14    62
# 15    66
# 16    95
# 17    55
# 18    94
# 19     2
# dtype: int64

# %%
my_ss.iloc[0] = 0
pd.cut(my_ss, bins=(0,25,50,75,101), labels=["D", "C", "B", "A"])
# Out:
# 0     NaN
# 1       D
# 2       D
# 3       D
# 4       D
# 5       A
# 6       C
# 7       C
# 8       A
# 9       A
# 10      B
# 11      C
# 12      C
# 13      B
# 14      B
# 15      B
# 16      A
# 17      B
# 18      A
# 19      D
# dtype: category
# Categories (4, object): ['D' < 'C' < 'B' < 'A']

# %%
my_ss.iloc[0] = 100
pd.cut(my_ss, bins=(-1,24,49,74,100), labels=["D", "C", "B", "A"])
# Out:
# 0     A
# 1     D
# 2     D
# 3     D
# 4     D
# 5     A
# 6     C
# 7     B
# 8     A
# 9     A
# 10    B
# 11    C
# 12    C
# 13    B
# 14    B
# 15    B
# 16    A
# 17    B
# 18    A
# 19    D
# dtype: category
# Categories (4, object): ['D' < 'C' < 'B' < 'A']

# %%
np.random.randint(0, 100, 20)
# Out:
# array([32, 78, 57, 76,  0, 87, 81, 22, 96, 43, 47, 56, 78, 93, 21, 68, 14,
#        36, 56, 85])

# %%
my_df = pd.DataFrame(np.random.randint(0, 100, 100), columns=["score"])
my_df
# Out:
#     score
# 0      45
# 1       7
# 2      66
# 3      33
# 4      35
# ..    ...
# 95     65
# 96     18
# 97     57
# 98     15
# 99     28
#
# [100 rows x 1 columns]

# %%
my_df['grade'] = pd.cut(my_df.score, bins=[-1,25,50,75,100], labels=["D","C", "B","A"])
my_df
# Out:
#     score grade
# 0      45     C
# 1       7     D
# 2      66     B
# 3      33     C
# 4      35     C
# ..    ...   ...
# 95     65     B
# 96     18     D
# 97     57     B
# 98     15     D
# 99     28     C
#
# [100 rows x 2 columns]

# %%
my_df1 = pd.DataFrame({"A": list("abca"), "B": list("bccd")}, dtype="category")
my_df1
# Out:
#    A  B
# 0  a  b
# 1  b  c
# 2  c  c
# 3  a  d

# %%
my_df1.dtypes
# Out:
# A    category
# B    category
# dtype: object

# %%
my_df1 = pd.DataFrame({"A": list("abca"), "B": list("bccd")}, dtype=pd.CategoricalDtype())
my_df1
# Out:
#    A  B
# 0  a  b
# 1  b  c
# 2  c  c
# 3  a  d

# %%
my_df1.dtypes
# Out:
# A    category
# B    category
# dtype: object

# %%
my_df1.A
# Out:
# 0    a
# 1    b
# 2    c
# 3    a
# Name: A, dtype: category
# Categories (3, object): ['a', 'b', 'c']

# %%
my_df1.B
# Out:
# 0    b
# 1    c
# 2    c
# 3    d
# Name: B, dtype: category
# Categories (3, object): ['b', 'c', 'd']

# %%
my_df2 = pd.DataFrame({"A": list("abca"), "B": list("bccd")})
my_df2.A.astype("category")
# Out:
# 0    a
# 1    b
# 2    c
# 3    a
# Name: A, dtype: category
# Categories (3, object): ['a', 'b', 'c']

# %%
my_df2.B.astype("category")
# Out:
# 0    b
# 1    c
# 2    c
# 3    d
# Name: B, dtype: category
# Categories (3, object): ['b', 'c', 'd']

# %%
my_ss4 = my_df2.B.astype("category")
my_ss4.iloc[0] = 'a'
my_ss4
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-fb27f14135a9> in <module>()
#       1 my_ss4 = my_df2.B.astype("category")
# ----> 2 my_ss4.iloc[0] = 'a'
#       3 my_ss4
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     668
#     669         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 670         iloc._setitem_with_indexer(indexer, value)
#     671
#     672     def _validate_key(self, key, axis: int):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#    1798             # actually do the set
#    1799             self.obj._consolidate_inplace()
# -> 1800             self.obj._mgr = self.obj._mgr.setitem(indexer=indexer, value=value)
#    1801             self.obj._maybe_update_cacher(clear=True)
#    1802
#
# ...

# %%
my_category = pd.CategoricalDtype(categories=list("abcd"))
my_category
# Out:
# CategoricalDtype(categories=['a', 'b', 'c', 'd'], ordered=False)

# %%
# 초중고
# 상중하
# 남녀
# 파이토치
# 텐서플로 2.0 = tensorflow + keras // 논문/학술
# 아메리칸 / 
# 승용차/화물차
my_category1 = pd.CategoricalDtype(categories=["d","c","b","a"], ordered=True)
my_category1
# Out:
# CategoricalDtype(categories=['d', 'c', 'b', 'a'], ordered=True)

# %%
my_df2.B.dtype
# Out:
# dtype('O')

# %%
my_df2.B
# Out:
# 0    b
# 1    c
# 2    c
# 3    d
# Name: B, dtype: object

# %%
my_ss10 = my_df2.B.astype(my_category1)
my_ss10
# Out:
# 0    b
# 1    c
# 2    c
# 3    d
# Name: B, dtype: category
# Categories (4, object): ['d' < 'c' < 'b' < 'a']

# %%
my_ss10.iloc[0] = 'a'
my_ss10
# Out:
# 0    a
# 1    c
# 2    c
# 3    d
# Name: B, dtype: category
# Categories (4, object): ['d' < 'c' < 'b' < 'a']

# %%
import torch

# %%
torch.rand(5,3)
# Out:
# tensor([[0.9319, 0.6316, 0.9149],
#         [0.4057, 0.3896, 0.5987],
#         [0.1513, 0.1604, 0.0696],
#         [0.5574, 0.1267, 0.3689],
#         [0.6152, 0.6787, 0.9715]])

# %% [markdown]
# ## Categorical Data
# - .cat.

# %%
my_df1
# Out:
#    A  B
# 0  a  b
# 1  b  c
# 2  c  c
# 3  a  d

# %%
my_df1.dtypes
# Out:
# A    category
# B    category
# dtype: object

# %%
my_df1.B.dtype
# Out:
# CategoricalDtype(categories=['b', 'c', 'd'], ordered=False)

# %%
my_category1
# Out:
# CategoricalDtype(categories=['d', 'c', 'b', 'a'], ordered=True)

# %%
my_df1.B = my_df1.B.cat.add_categories(['a'])
my_df1.B.dtype
# Out:
# CategoricalDtype(categories=['b', 'c', 'd', 'a'], ordered=False)

# %%
my_df1.B.cat.categories = ['d', 'c', 'b', 'a']
my_df1.B
# Out:
# 0    d
# 1    c
# 2    c
# 3    b
# Name: B, dtype: category
# Categories (4, object): ['d', 'c', 'b', 'a']

# %%
my_df1.B.cat.rename_categories(['a', 'b', 'c', 'd'])
# Out:
# 0    a
# 1    b
# 2    b
# 3    c
# Name: B, dtype: category
# Categories (4, object): ['a', 'b', 'c', 'd']

# %%
my_df1.B
# Out:
# 0    d
# 1    c
# 2    c
# 3    b
# Name: B, dtype: category
# Categories (4, object): ['d', 'c', 'b', 'a']

# %%
emy_df1.B.cat.rename_categories({'a': 1, 'b': 2, 'c':3, 'd':4})
# Out:
# 0    4
# 1    3
# 2    3
# 3    2
# Name: B, dtype: category
# Categories (4, int64): [4, 3, 2, 1]

# %%
my_ss4 = my_df1.B.cat.as_ordered()
my_ss4
# Out:
# 0    d
# 1    c
# 2    c
# 3    b
# Name: B, dtype: category
# Categories (4, object): ['d' < 'c' < 'b' < 'a']

# %%
my_ss4.sort_values()
# Out:
# 0    d
# 1    c
# 2    c
# 3    b
# Name: B, dtype: category
# Categories (4, object): ['d' < 'c' < 'b' < 'a']

# %%
my_ss4.min()
# Out:
# 'd'

# %%
my_ss4.max()
# Out:
# 'b'

# %%
my_ss4.cat.as_unordered()
# Out:
# 0    d
# 1    c
# 2    c
# 3    b
# Name: B, dtype: category
# Categories (4, object): ['d', 'c', 'b', 'a']

# %%
my_index = ["h", "i", "j", "k", "l", "m", "n"]
my_categories = pd.Categorical(["a", "a", "a", "a", "a", "a", "a"], categories=["a", "b"])
my_list = [1, 1, 1, 1, 1, 1, 1]

# %%
my_df = pd.DataFrame({"values": my_list, "cats": my_categories}, index=my_index)
my_df
# Out:
#    values cats
# h       1    a
# i       1    a
# j       1    a
# k       1    a
# l       1    a
# m       1    a
# n       1    a

# %%
my_df.iloc[2:4] = [[2, 'b'], [2, 'b']]
my_df
# Out:
#    values cats
# h       1    a
# i       1    a
# j       2    b
# k       2    b
# l       1    a
# m       1    a
# n       1    a

# %%
my_df.loc['j':'k', 'cats']
# Out:
# j    b
# k    b
# Name: cats, dtype: category
# Categories (2, object): ['a', 'b']

# %%
my_df.loc['j': 'k', 'cats'] = pd.Categorical(['a', 'a'], categories=['a', 'b'])
my_df
# Out:
#    values cats
# h       1    a
# i       1    a
# j       2    a
# k       2    a
# l       1    a
# m       1    a
# n       1    a

# %%
my_df.loc['j': 'k', 'cats'] = pd.Categorical(['a','a'], categories=['a', 'b', 'c'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-02cfab2d3c1c> in <module>()
# ----> 1 my_df.loc['j': 'k', 'cats'] = pd.Categorical(['a','a'], categories=['a', 'b', 'c'])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     668
#     669         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 670         iloc._setitem_with_indexer(indexer, value)
#     671
#     672     def _validate_key(self, key, axis: int):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#    1741                     # we have an equal len list/ndarray
#    1742                     # We only get here with len(labels) == len(ilocs) == 1
# -> 1743                     isetter(ilocs[0], value)
#    1744
# ...

# %%
import seaborn as sns
my_titanic = sns.load_dataset('titanic')
my_titanic
# Out:
#      survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0           0       3    male  22.0  ...   NaN  Southampton     no  False
# 1           1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2           1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3           1       1  female  35.0  ...     C  Southampton    yes  False
# 4           0       3    male  35.0  ...   NaN  Southampton     no   True
# ..        ...     ...     ...   ...  ...   ...          ...    ...    ...
# 886         0       2    male  27.0  ...   NaN  Southampton     no   True
# 887         1       1  female  19.0  ...     B  Southampton    yes   True
# 888         0       3  female   NaN  ...   NaN  Southampton     no  False
# 889         1       1    male  26.0  ...     C    Cherbourg    yes   True
# 890         0       3    male  32.0  ...   NaN   Queenstown     no   True
#
# [891 rows x 15 columns]

# %%
my_titanic.sex.dtype
# Out:
# dtype('O')

# %%
my_titanic.sex.nbytes
# Out:
# 7128

# %%
my_titanic.sex.astype('category')
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: sex, Length: 891, dtype: category
# Categories (2, object): ['female', 'male']

# %%
my_titanic.sex.astype('category').nbytes
# Out:
# 907

# %%
my_titanic['class']
# Out:
# 0       Third
# 1       First
# 2       Third
# 3       First
# 4       Third
#         ...
# 886    Second
# 887     First
# 888     Third
# 889     First
# 890     Third
# Name: class, Length: 891, dtype: category
# Categories (3, object): ['First', 'Second', 'Third']

# %%
my_data = np.random.randint(0, 100, 1000)
my_data
# Out:
# array([30, 78,  6, 43, 58, 85, 60, 79, 83, 45, 80, 84, 19, 63, 41,  3, 78,
#        48, 70, 43, 96, 63, 46, 21, 25, 50, 20, 78, 25, 68, 69, 84, 96, 50,
#        77, 14, 30, 40, 37, 85, 85, 73, 77, 54, 98,  4, 83, 62, 54, 98, 15,
#        12, 57,  6, 69, 82, 21, 33, 13, 98, 26, 88, 43, 23, 18, 99, 24, 24,
#        55, 63, 29, 77, 82, 22, 52, 61, 23, 43, 79, 60,  5,  4, 73, 51, 66,
#        41, 89, 95, 80, 37, 18, 52, 25, 19,  1, 20, 65, 56, 73,  6,  6, 24,
#        87,  8,  4,  6, 56, 13,  4, 55, 40,  7, 37, 37, 24, 10, 19, 54, 15,
#        46, 89, 51, 14, 62, 25,  3, 71, 51, 94, 70, 53, 80, 14, 11, 72, 85,
#         7, 96, 44, 41, 27, 57, 30, 57, 82,  4, 29, 38, 56, 31, 28,  9, 31,
#        36, 90, 92, 57,  4, 27, 99, 84, 96, 11, 79, 21, 11, 21, 34, 72, 59,
#        18, 83, 77,  7, 94, 11, 70,  8, 69,  0, 12, 94, 32, 69, 76, 72,  6,
#        91, 44, 12, 54, 13, 23, 55, 95,  1, 84, 22,  9,  8, 33, 14,  1, 61,
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)
